# %%
import pandas as pd
import numpy as np
from IPython.display import display
import gc

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
trade = pd.read_csv("../v_trade.csv")
trade_test = pd.read_csv("../v_trade_test.csv")
login = pd.read_csv("../v_login.csv")
login_test = pd.read_csv("../v_login_test.csv")

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, fbeta_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import xgboost as xgb

# %%
feature = pd.read_csv("1206_feature_c.csv")

# %%
feature = feature.drop(['over'], axis=1)

# %%
s_column = feature.columns[6:]

# %%
train_df = pd.merge(feature, trade[['row_name']], how='inner', on=['row_name'])
test_df = pd.merge(feature, trade_test[['row_name']], how='inner', on=['row_name'])

# %%
X_train = train_df[train_df.time <= '2015-04-30 00:00:00']
X_val = train_df[train_df.time > '2015-04-30 00:00:00']
display(X_train.shape)
display(X_val.shape)
display(test_df.shape)
display(len(X_train[X_train.actual_label==1])/len(X_train))
display(len(X_val[X_val.actual_label==1])/len(X_val))
# Out:
# (28250, 981)
# (16969, 981)
# (6652, 981)
# 0.07086725663716814
# 0.047969827332194

# %%
display(train_df.groupby(['pesudo_label1']).size())
display(train_df.groupby(['pesudo_label2']).size())
display(train_df.groupby(['actual_label']).size())
# Out:
# pesudo_label1
# 0    42566
# 1     2653
# dtype: int64
# pesudo_label2
# 0    42214
# 1     2601
# 2      404
# dtype: int64
# actual_label
# 0    42403
# 1     2816
# dtype: int64

# %%
def eval_fbeta(preds, dtrain):
    return 'fbeta', 1-fbeta_score(dtrain.get_label(), preds >= 0.5, 0.1)

# %%
train2 = X_train[['row_name','pesudo_label1','pesudo_label2','actual_label']]
val2 = X_val[['row_name','pesudo_label1','pesudo_label2','actual_label']]

# %%
s_column_2 = []
for ss in s_column:
    if (ss != "本次登录时长" and ss != "14_30天登录与交易的最大时间间隔" and
       ss != "14_30天登录与交易的最小时间间隔" and ss != "14_30天登录与交易的平均时间间隔" and
       ss != "本次登录与本段交易时间间隔" and ss != "本段交易数量" and
       ss != "上段交易登录与交易的时间间隔" and ss != "历史交易登录与交易的平均时间间隔"):
        s_column_2.append(ss)

# %%
clf4 = lgb.LGBMClassifier(boosting_type='dart', learning_rate=0.14, max_depth=14, n_estimators=1150, colsample_bytree=0.82, 
                          min_split_gain=1.2, max_bin=730, reg_lambda=0.9, is_unbalance=True, random_state=400, subsample=0.9)
clf4.fit(X_train[s_column_2], X_train.pesudo_label1, eval_metric=eval_fbeta)
gc.collect()
# Out:
# 160

# %%
train2['clf4_prob'] = clf4.predict_proba(X_train[s_column_2])[:,1]
val2['clf4_prob'] = clf4.predict_proba(X_val[s_column_2])[:,1]
# Out:
# /Users/admin/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/admin/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
threshold = 0.99
display(accuracy_score(train2[train2.clf4_prob>=threshold].pesudo_label1, train2[train2.clf4_prob>=threshold].clf4_prob>=threshold))
display(accuracy_score(val2[val2.clf4_prob>=threshold].pesudo_label1, val2[val2.clf4_prob>=threshold].clf4_prob>=threshold))
print("====")
display(accuracy_score(train2[train2.clf4_prob>=threshold].actual_label, train2[train2.clf4_prob>=threshold].clf4_prob>=threshold))
display(accuracy_score(val2[val2.clf4_prob>=threshold].actual_label, val2[val2.clf4_prob>=threshold].clf4_prob>=threshold))
# Out:
# 0.99818511796733211
# 0.90000000000000002
# ====
# 0.99637023593466423
# 0.91428571428571426

# %%
pd.merge(trade, val2[(val2.actual_label == 0) & (val2.clf4_prob >= 0.99)], how='inner', on=['row_name'])
# Out:
#    rowkey                 time      id  is_risk            row_name  \
# 0  616142  2015-05-05 21:43:04   90845        0  train_trade_616142
# 1  682148  2015-05-20 14:50:03  153886        0  train_trade_682148
# 2  714546  2015-05-27 09:57:26  106885        0  train_trade_714546
# 3  738037  2015-06-01 07:54:55  128481        0  train_trade_738037
# 4  884465  2015-06-18 17:53:45   22533        0  train_trade_884465
# 5  738097  2015-06-01 08:05:03  128481        0  train_trade_738097
#
#    pesudo_label1  pesudo_label2  actual_label  clf3_prob  clf4_prob
# 0              0              2             0   0.969501   0.991451
# 1              0              0             0   0.999328   0.999641
# 2              0              0             0   0.998776   0.999593
# 3              0              0             0   0.899355   0.994972
# 4              0              0             0   0.968028   0.995820
# 5              0              0             0   0.899355   0.994972

# %%
feature_df4 = pd.DataFrame()
feature_df4['feature'] = s_column_2
feature_df4['score'] = clf4.feature_importance()
feature_df4.sort_values(['score'], ascending=False)
# Out:
# /Users/admin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:75: DeprecationWarning: Function feature_importance is deprecated; Use attribute feature_importances_ instead.
#   warnings.warn(msg, category=DeprecationWarning)
#                                 feature  score
# 844                 本次登录城市在45_60d内被登录次数   2198
# 521            本次登录设备登录结果为1在45_60d内登录次数   1126
# 843                 本次登录城市在30_45d内被登录次数   1013
# 73                      14_30天内交易最大间隔天数    847
# 881                 本次登录IP在45_60d内被登录次数    799
# 508                  本次登录设备在45_60d内登录次数    769
# 74                      14_30天内交易最小间隔天数    659
# 754           本次登录设备45_60d内登录其他用户次数结果为1    622
# 81                    14_30天内交易时间0-3点占比    604
# 187                          本次登录类型是否为3    566
# 813                  1d内登录设备中新设备数量且结果为1    485
# 71                          14_30天内交易段数    476
# 78                  14_30天内交易时间13-17点次数    457
# 190                            本次登录来源为2    454
# 964                        用户全局是否只有本段交易    441
# 812                  6h内登录设备中新设备数量且结果为1    430
# 94                      14_30天内交易是否为节假日    414
# 845                     本次登录城市在历史内被登录次数    407
# 92                         14_30天内交易为周六    407
# 520            本次登录设备登录结果为1在30_45d内登录次数    389
# 507                  本次登录设备在30_45d内登录次数    385
# 88                         14_30天内交易为周二    380
# 534           本次登录设备登录结果为31在45_60d内登录次数    362
# 84                  14_30天内交易时间13-17点占比    354
# 496                         本次登录设备是否新设备    353
# 185                          本次登录类型是否为1    352
# 87                         14_30天内交易为周一    333
# 965                    用户全局行为是否全在前后24h内    329
# 90                         14_30天内交易为周四    309
# 497                       本次登录设备是否成功新设备    303
# 887                          1d内登录不同IP数    298
# 189                            本次登录来源为1    294
# 72                      14_30天内交易平均间隔天数    280
# 169                     上上段交易登录与交易的时间间隔    266
# 91                         14_30天内交易为周五    264
# 83                  14_30天内交易时间11-12点占比    247
# 86                  14_30天内交易时间21-23点占比    237
# 818                      1d内登录不同设备数结果为1    236
# 839                   本次登录城市在1_3d内被登录次数    222
# 838                  本次登录城市在2h_1d内被登录次数    218
# 841                  本次登录城市在7_14d内被登录次数    216
# 82                   14_30天内交易时间4-10点占比    215
# 85                  14_30天内交易时间18-20点占比    213
# 828                     1d内登录不同设备数结果为负数    202
# 966                         本次设备是交易设备概率    201
# 80                  14_30天内交易时间21-23点次数    199
# 808                          1d内登录不同设备数    195
# 823                     1d内登录不同设备数结果为31    191
# 807                          6h内登录不同设备数    189
# 76                   14_30天内交易时间4-10点次数    187
# 153                             今年第几段交易    183
# 154                       上段交易内交易时间0-3点    169
# 188                           本次登录来源为10    154
# 89                         14_30天内交易为周三    153
# 560           本次登录设备登录结果为正数在45_60d内登录次数    148
# 93                         14_30天内交易为周日    145
# 200                20min内登录结果为1登录来源为1次数    145
# 876                   本次登录IP在1_3d内被登录次数    141
# 152                            是否今年初次交易    139
# 77                  14_30天内交易时间11-12点次数    139
# 95                   14_30天内交易是否为节假日前一天    137
# 850                          1d内登录不同城市数    136
# 509                      本次登录设备在历史内登录次数    124
# 880                 本次登录IP在30_45d内被登录次数    119
# 817                      6h内登录不同设备数结果为1    116
# 840                   本次登录城市在3_7d内被登录次数    113
# 502                   本次登录设备在2h_1d内登录次数    112
# 0                            本段交易时间0-3点    112
# 770          本次登录设备45_60d内登录其他用户次数结果为31    111
# 161                          上段交易内交易为周二    109
# 522                本次登录设备登录结果为1在历史内登录次数    109
# 2                          本段交易时间11-12点    106
# 162                          上段交易内交易为周三    101
# 12                              本段交易为周日     99
# 571                上段交易登录设备在30_45d内登录次数     94
# 834                          本次登录是否为新城市     92
# 266                   2h内登录结果为1登录来源为1次数     87
# 566                 上段交易登录设备在2h_1d内登录次数     87
# 809               10min内登录设备中新设备数量且结果为1     87
# 811                  2h内登录设备中新设备数量且结果为1     86
# 569                 上段交易登录设备在7_14d内登录次数     86
# 157                     上段交易内交易时间13-17点     85
# 559           本次登录设备登录结果为正数在30_45d内登录次数     83
# 872                本次登录IP在0_30min内被登录次数     83
# 921                     90min内登录结果为31次数     83
# 822                     6h内登录不同设备数结果为31     81
# 516              本次登录设备登录结果为1在1_3d内登录次数     77
# 364              上段交易2h内登录结果为1登录来源为10次数     75
# 518             本次登录设备登录结果为1在7_14d内登录次数     74
# 572           上段交易登录设备登录结果为1在10min内登录次数     74
# 547           本次登录设备登录结果为负数在45_60d内登录次数     73
# 567                  上段交易登录设备在1_3d内登录次数     73
# 186                          本次登录类型是否为2     69
# 875                  本次登录IP在2h_1d内被登录次数     69
# 564                    上段交易登录设备在1h内登录次数     69
# 537            本次登录设备登录结果为负数在20min内登录次数     67
# 924                     120min内登录结果为1次数     65
# 835                本次登录城市在0_30min内被登录次数     65
# 8                               本段交易为周三     65
# 568                  上段交易登录设备在3_7d内登录次数     65
# 75                    14_30天内交易时间0-3点次数     63
# 182                         上上段交易内交易为周日     62
# 883                       10min内登录不同IP数     62
# 11                              本段交易为周六     59
# 365               上段交易2h内登录结果为1登录来源为1次数     58
# 503                    本次登录设备在1_3d内登录次数     58
# 755               本次登录设备历史内登录其他用户次数结果为1     56
# 500                      本次登录设备在1h内登录次数     56
# 896                     6h内登录不同IP数结果为31     55
# 892                      1d内登录不同IP数结果为1     54
# 849                          6h内登录不同城市数     53
# 886                          6h内登录不同IP数     53
# 745               本次登录设备2h内登录其他用户次数结果为1     53
# 513                本次登录设备登录结果为1在1h内登录次数     52
# 878                  本次登录IP在7_14d内被登录次数     52
# 163                          上段交易内交易为周四     52
# 498                   本次登录设备在10min内登录次数     50
# 625               上上段交易登录设备在30_45d内登录次数     50
# 920                      90min内登录结果为1次数     50
# 753           本次登录设备30_45d内登录其他用户次数结果为1     50
# 155                      上段交易内交易时间4-10点     49
# 865                     1d内登录不同城市数结果为负数     48
# 836               本次登录城市在30min_1h内被登录次数     48
# 79                  14_30天内交易时间18-20点次数     47
# 201                20min内登录结果为1登录来源为2次数     47
# 167                       上段交易内交易是否为节假日     46
# 233                   1h内登录结果为1登录来源为1次数     45
# 882                     本次登录IP在历史内被登录次数     45
# 912                      20min内登录结果为1次数     44
# 846                       10min内登录不同城市数     44
# 523            本次登录设备登录结果为31在10min内登录次数     44
# 168                    上段交易内交易是否为节假日前一天     43
# 908                      10min内登录结果为1次数     43
# 871                          本次登录是否为新IP     42
# 821                     2h内登录不同设备数结果为31     41
# 855                      1d内登录不同城市数结果为1     41
# 160                          上段交易内交易为周一     41
# 505                   本次登录设备在7_14d内登录次数     40
# 925                    120min内登录结果为31次数     39
# 267                   2h内登录结果为1登录来源为2次数     39
# 170                      上上段交易内交易时间0-3点     39
# 171                     上上段交易内交易时间4-10点     39
# 515             本次登录设备登录结果为1在2h_1d内登录次数     39
# 636         上上段交易登录设备登录结果为1在30_45d内登录次数     39
# 159                     上段交易内交易时间21-23点     39
# 582          上段交易登录设备登录结果为1在30_45d内登录次数     38
# 586             上段交易登录设备登录结果为31在1h内登录次数     37
# 6                               本段交易为周一     36
# 888                   10min内登录不同IP数结果为1     35
# 3                          本段交易时间13-17点     34
# 178                         上上段交易内交易为周三     34
# 915                     20min内登录结果为负数次数     34
# 833                     1d内登录不同设备数结果为正数     33
# 917                     45min内登录结果为31次数     33
# 848                          2h内登录不同城市数     33
# 510             本次登录设备登录结果为1在10min内登录次数     32
# 837                   本次登录城市在1_2h内被登录次数     32
# 885                          2h内登录不同IP数     31
# 816                      2h内登录不同设备数结果为1     30
# 535               本次登录设备登录结果为31在历史内登录次数     29
# 184                   上上段交易内交易是否为节假日前一天     26
# 166                          上段交易内交易为周日     25
# 14                        本段交易是否为节假日前一天     25
# 195                           本次登录来源为16     24
# 156                     上段交易内交易时间11-12点     24
# 804                       10min内登录不同设备数     24
# 913                     20min内登录结果为31次数     24
# 583          上段交易登录设备登录结果为31在10min内登录次数     23
# 234                   1h内登录结果为1登录来源为2次数     23
# 860                     1d内登录不同城市数结果为31     23
# 805                       30min内登录不同设备数     23
# 810               30min内登录设备中新设备数量且结果为1     22
# 615         上段交易登录设备登录结果为正数在30_45d内登录次数     22
# 164                          上段交易内交易为周五     22
# 528            本次登录设备登录结果为31在2h_1d内登录次数     22
# 533           本次登录设备登录结果为31在30_45d内登录次数     22
# 10                              本段交易为周五     22
# 578            上段交易登录设备登录结果为1在1_3d内登录次数     22
# 930                  本次登录设备30min内连接IP次数     22
# 211               20min内登录结果为31登录来源为1次数     21
# 172                    上上段交易内交易时间11-12点     21
# 550            本次登录设备登录结果为正数在20min内登录次数     21
# 232                  1h内登录结果为1登录来源为10次数     20
# 847                       30min内登录不同城市数     20
# 536            本次登录设备登录结果为负数在10min内登录次数     20
# 851                   10min内登录不同城市数结果为1     19
# 546           本次登录设备登录结果为负数在30_45d内登录次数     19
# 897                     1d内登录不同IP数结果为31     19
# 890                      2h内登录不同IP数结果为1     18
# 9                               本段交易为周四     18
# 176                         上上段交易内交易为周一     18
# 929                  本次登录设备15min内连接IP次数     16
# 916                      45min内登录结果为1次数     16
# 910                     10min内登录结果为正数次数     16
# 5                          本段交易时间21-23点     16
# 815                   30min内登录不同设备数结果为1     16
# 902                     1d内登录不同IP数结果为负数     16
# 575              上段交易登录设备登录结果为1在1h内登录次数     15
# 563                 上段交易登录设备在30min内登录次数     15
# 579            上段交易登录设备登录结果为1在3_7d内登录次数     14
# 750             本次登录设备2_7d内登录其他用户次数结果为1     14
# 854                      6h内登录不同城市数结果为1     14
# 551            本次登录设备登录结果为正数在30min内登录次数     14
# 825                  30min内登录不同设备数结果为负数     14
# 517              本次登录设备登录结果为1在3_7d内登录次数     14
# 4                          本段交易时间18-20点     14
# 891                      6h内登录不同IP数结果为1     14
# 174                    上上段交易内交易时间18-20点     14
# 859                     6h内登录不同城市数结果为31     13
# 806                          2h内登录不同设备数     13
# 580           上段交易登录设备登录结果为1在7_14d内登录次数     13
# 588          上段交易登录设备登录结果为31在2h_1d内登录次数     13
# 277                  2h内登录结果为31登录来源为1次数     13
# 538            本次登录设备登录结果为负数在30min内登录次数     12
# 529             本次登录设备登录结果为31在1_3d内登录次数     12
# 884                       30min内登录不同IP数     12
# 158                     上段交易内交易时间18-20点     12
# 173                    上上段交易内交易时间13-17点     12
# 13                           本段交易是否为节假日     12
# 889                   30min内登录不同IP数结果为1     12
# 7                               本段交易为周二     12
# 909                     10min内登录结果为31次数     11
# 928                   本次登录设备5min内连接IP次数     11
# 831                     2h内登录不同设备数结果为正数     11
# 265                  2h内登录结果为1登录来源为10次数     11
# 1                           本段交易时间4-10点     11
# 802          本次登录设备45_60d内登录其他用户次数结果为正数     10
# 165                          上段交易内交易为周六     10
# 552               本次登录设备登录结果为正数在1h内登录次数     10
# 874                   本次登录IP在1_2h内被登录次数     10
# 931                  本次登录设备60min内连接IP次数     10
# 499                   本次登录设备在30min内登录次数     10
# 177                         上上段交易内交易为周二     10
# 936                  上上段登录设备5min内连接IP次数      9
# 577           上段交易登录设备登录结果为1在2h_1d内登录次数      9
# 814                   10min内登录不同设备数结果为1      9
# 331              上段交易1h内登录结果为1登录来源为10次数      9
# 526               本次登录设备登录结果为31在1h内登录次数      9
# 549            本次登录设备登录结果为正数在10min内登录次数      9
# 573           上段交易登录设备登录结果为1在20min内登录次数      8
# 827                     6h内登录不同设备数结果为负数      8
# 524            本次登录设备登录结果为31在20min内登录次数      8
# 212               20min内登录结果为31登录来源为2次数      8
# 463             上上段交易2h内登录结果为1登录来源为10次数      8
# 873               本次登录IP在30min_1h内被登录次数      7
# 877                   本次登录IP在3_7d内被登录次数      7
# 803              本次登录设备历史内登录其他用户次数结果为正数      7
# 278                  2h内登录结果为31登录来源为2次数      7
# 738               本次登录设备45_60d内登录其他用户次数      7
# 585          上段交易登录设备登录结果为31在30min内登录次数      7
# 637         上上段交易登录设备登录结果为31在10min内登录次数      7
# 622                 上上段交易登录设备在3_7d内登录次数      7
# 852                   30min内登录不同城市数结果为1      7
# 594          上段交易登录设备登录结果为负数在10min内登录次数      7
# 584          上段交易登录设备登录结果为31在20min内登录次数      6
# 199               20min内登录结果为1登录来源为10次数      6
# 945                  本次登录设备15min内连接城市次数      6
# 870                     1d内登录不同城市数结果为正数      6
# 504                    本次登录设备在3_7d内登录次数      6
# 501                    本次登录设备在1_2h内登录次数      6
# 175                    上上段交易内交易时间21-23点      6
# 617                上上段交易登录设备在30min内登录次数      6
# 933                上段交易登录设备15min内连接IP次数      5
# 820                  30min内登录不同设备数结果为31      5
# 565                  上段交易登录设备在1_2h内登录次数      5
# 853                      2h内登录不同城市数结果为1      5
# 511             本次登录设备登录结果为1在20min内登录次数      5
# 574           上段交易登录设备登录结果为1在30min内登录次数      5
# 244                  1h内登录结果为31登录来源为1次数      5
# 946                  本次登录设备30min内连接城市次数      5
# 332               上段交易1h内登录结果为1登录来源为1次数      5
# 927                    120min内登录结果为负数次数      5
# 919                     45min内登录结果为负数次数      4
# 366               上段交易2h内登录结果为1登录来源为2次数      4
# 464              上上段交易2h内登录结果为1登录来源为1次数      4
# 623                上上段交易登录设备在7_14d内登录次数      4
# 299            上段交易20min内登录结果为1登录来源为1次数      4
# 541            本次登录设备登录结果为负数在2h_1d内登录次数      4
# 376              上段交易2h内登录结果为31登录来源为1次数      4
# 562                 上段交易登录设备在10min内登录次数      4
# 180                         上上段交易内交易为周五      4
# 832                     6h内登录不同设备数结果为正数      4
# 654          上上段交易登录设备登录结果为负数在1_3d内登录次数      3
# 181                         上上段交易内交易为周六      3
# 593         上段交易登录设备登录结果为31在30_45d内登录次数      3
# 527             本次登录设备登录结果为31在1_2h内登录次数      3
# 525            本次登录设备登录结果为31在30min内登录次数      3
# 944                   本次登录设备5min内连接城市次数      3
# 858                     2h内登录不同城市数结果为31      3
# 918                     45min内登录结果为正数次数      3
# 868                     2h内登录不同城市数结果为正数      3
# 300            上段交易20min内登录结果为1登录来源为2次数      3
# 333               上段交易1h内登录结果为1登录来源为2次数      3
# 926                    120min内登录结果为正数次数      3
# 829                  10min内登录不同设备数结果为正数      3
# 824                  10min内登录不同设备数结果为负数      3
# 576            上段交易登录设备登录结果为1在1_2h内登录次数      2
# 183                      上上段交易内交易是否为节假日      2
# 744               本次登录设备1h内登录其他用户次数结果为1      2
# 742            本次登录设备20min内登录其他用户次数结果为1      2
# 923                     90min内登录结果为负数次数      2
# 465              上上段交易2h内登录结果为1登录来源为2次数      2
# 514              本次登录设备登录结果为1在1_2h内登录次数      2
# 746             本次登录设备2_6h内登录其他用户次数结果为1      2
# 729                   本次登录设备2h内登录其他用户次数      2
# 616                上上段交易登录设备在10min内登录次数      2
# 899                  30min内登录不同IP数结果为负数      2
# 901                     6h内登录不同IP数结果为负数      2
# 862                  30min内登录不同城市数结果为负数      2
# 179                         上上段交易内交易为周四      2
# 914                     20min内登录结果为正数次数      1
# 932                 上段交易登录设备5min内连接IP次数      1
# 245                  1h内登录结果为31登录来源为2次数      1
# 830                  30min内登录不同设备数结果为正数      1
# 906                     6h内登录不同IP数结果为正数      1
# 343              上段交易1h内登录结果为31登录来源为1次数      1
# 950                上段交易登录设备30min内连接城市次数      1
# 431              上上段交易1h内登录结果为1登录来源为1次数      1
# 864                     6h内登录不同城市数结果为负数      1
# 633           上上段交易登录设备登录结果为1在3_7d内登录次数      1
# 628          上上段交易登录设备登录结果为1在30min内登录次数      1
# 963  本次登录20min内登录存在登录结果为1后结果为其他的情况且设备不同      1
# 618                   上上段交易登录设备在1h内登录次数      1
# 621                 上上段交易登录设备在1_3d内登录次数      1
# 863                     2h内登录不同城市数结果为负数      1
# 476             上上段交易2h内登录结果为31登录来源为2次数      1
# 432              上上段交易1h内登录结果为1登录来源为2次数      1
# 826                     2h内登录不同设备数结果为负数      1
# 758           本次登录设备20min内登录其他用户次数结果为31      1
# 643          上上段交易登录设备登录结果为31在1_3d内登录次数      1
# 587           上段交易登录设备登录结果为31在1_2h内登录次数      1
# 377              上段交易2h内登录结果为31登录来源为2次数      1
# 953                 上上段登录设备15min内连接城市次数      1
# 590           上段交易登录设备登录结果为31在3_7d内登录次数      1
# 591          上段交易登录设备登录结果为31在7_14d内登录次数      1
# 298           上段交易20min内登录结果为1登录来源为10次数      1
# 934                上段交易登录设备30min内连接IP次数      1
# 819                  10min内登录不同设备数结果为31      1
# 894                  30min内登录不同IP数结果为31      1
# 769          本次登录设备30_45d内登录其他用户次数结果为31      1
# 638         上上段交易登录设备登录结果为31在20min内登录次数      1
# 760              本次登录设备1h内登录其他用户次数结果为31      1
# 639         上上段交易登录设备登录结果为31在30min内登录次数      1
# 761              本次登录设备2h内登录其他用户次数结果为31      1
# 627          上上段交易登录设备登录结果为1在20min内登录次数      0
# 626          上上段交易登录设备登录结果为1在10min内登录次数      0
# 664         上上段交易登录设备登录结果为正数在2h_1d内登录次数      0
# 665          上上段交易登录设备登录结果为正数在1_3d内登录次数      0
# 651            上上段交易登录设备登录结果为负数在1h内登录次数      0
# 663          上上段交易登录设备登录结果为正数在1_2h内登录次数      0
# 650         上上段交易登录设备登录结果为负数在30min内登录次数      0
# 658        上上段交易登录设备登录结果为负数在30_45d内登录次数      0
# 662            上上段交易登录设备登录结果为正数在1h内登录次数      0
# 624               上上段交易登录设备在14_30d内登录次数      0
# 657        上上段交易登录设备登录结果为负数在14_30d内登录次数      0
# 656         上上段交易登录设备登录结果为负数在7_14d内登录次数      0
# 653         上上段交易登录设备登录结果为负数在2h_1d内登录次数      0
# 655          上上段交易登录设备登录结果为负数在3_7d内登录次数      0
# 652          上上段交易登录设备登录结果为负数在1_2h内登录次数      0
# 629             上上段交易登录设备登录结果为1在1h内登录次数      0
# 642         上上段交易登录设备登录结果为31在2h_1d内登录次数      0
# 661         上上段交易登录设备登录结果为正数在30min内登录次数      0
# 641          上上段交易登录设备登录结果为31在1_2h内登录次数      0
# 644          上上段交易登录设备登录结果为31在3_7d内登录次数      0
# 645         上上段交易登录设备登录结果为31在7_14d内登录次数      0
# 640            上上段交易登录设备登录结果为31在1h内登录次数      0
# 646        上上段交易登录设备登录结果为31在14_30d内登录次数      0
# 647        上上段交易登录设备登录结果为31在30_45d内登录次数      0
# 648         上上段交易登录设备登录结果为负数在10min内登录次数      0
# 630           上上段交易登录设备登录结果为1在1_2h内登录次数      0
# 660         上上段交易登录设备登录结果为正数在20min内登录次数      0
# 649         上上段交易登录设备登录结果为负数在20min内登录次数      0
# 634          上上段交易登录设备登录结果为1在7_14d内登录次数      0
# 635         上上段交易登录设备登录结果为1在14_30d内登录次数      0
# 632           上上段交易登录设备登录结果为1在1_3d内登录次数      0
# 631          上上段交易登录设备登录结果为1在2h_1d内登录次数      0
# 659         上上段交易登录设备登录结果为正数在10min内登录次数      0
# 866                  10min内登录不同城市数结果为正数      0
# 620                上上段交易登录设备在2h_1d内登录次数      0
# 595          上段交易登录设备登录结果为负数在20min内登录次数      0
# 940                 历史登录设备5min内连接IP平均次数      0
# 941                历史登录设备15min内连接IP平均次数      0
# 592         上段交易登录设备登录结果为31在14_30d内登录次数      0
# 942                历史登录设备30min内连接IP平均次数      0
# 943                历史登录设备60min内连接IP平均次数      0
# 589           上段交易登录设备登录结果为31在1_3d内登录次数      0
# 947                  本次登录设备60min内连接城市次数      0
# 948                 上段交易登录设备5min内连接城市次数      0
# 949                上段交易登录设备15min内连接城市次数      0
# 951                上段交易登录设备60min内连接城市次数      0
# 952                  上上段登录设备5min内连接城市次数      0
# 581          上段交易登录设备登录结果为1在14_30d内登录次数      0
# 954                 上上段登录设备30min内连接城市次数      0
# 955                 上上段登录设备60min内连接城市次数      0
# 956                 历史登录设备5min内连接城市平均次数      0
# 957                历史登录设备15min内连接城市平均次数      0
# 958                历史登录设备30min内连接城市平均次数      0
# 959                历史登录设备60min内连接城市平均次数      0
# 960       本次登录10min内登录存在登录结果为1后结果为其他的情况      0
# 961       本次登录20min内登录存在登录结果为1后结果为其他的情况      0
# 962  本次登录10min内登录存在登录结果为1后结果为其他的情况且设备不同      0
# 939                 上上段登录设备60min内连接IP次数      0
# 596          上段交易登录设备登录结果为负数在30min内登录次数      0
# 619                 上上段交易登录设备在1_2h内登录次数      0
# 938                 上上段登录设备30min内连接IP次数      0
# 614         上段交易登录设备登录结果为正数在14_30d内登录次数      0
# 613          上段交易登录设备登录结果为正数在7_14d内登录次数      0
# 612           上段交易登录设备登录结果为正数在3_7d内登录次数      0
# 611           上段交易登录设备登录结果为正数在1_3d内登录次数      0
# 610          上段交易登录设备登录结果为正数在2h_1d内登录次数      0
# 609           上段交易登录设备登录结果为正数在1_2h内登录次数      0
# 608             上段交易登录设备登录结果为正数在1h内登录次数      0
# 607          上段交易登录设备登录结果为正数在30min内登录次数      0
# 606          上段交易登录设备登录结果为正数在20min内登录次数      0
# 605          上段交易登录设备登录结果为正数在10min内登录次数      0
# 604         上段交易登录设备登录结果为负数在30_45d内登录次数      0
# 603         上段交易登录设备登录结果为负数在14_30d内登录次数      0
# 602          上段交易登录设备登录结果为负数在7_14d内登录次数      0
# 601           上段交易登录设备登录结果为负数在3_7d内登录次数      0
# 600           上段交易登录设备登录结果为负数在1_3d内登录次数      0
# 599          上段交易登录设备登录结果为负数在2h_1d内登录次数      0
# 598           上段交易登录设备登录结果为负数在1_2h内登录次数      0
# 935                上段交易登录设备60min内连接IP次数      0
# 937                 上上段登录设备15min内连接IP次数      0
# 667         上上段交易登录设备登录结果为正数在7_14d内登录次数      0
# 597             上段交易登录设备登录结果为负数在1h内登录次数      0
# 666          上上段交易登录设备登录结果为正数在3_7d内登录次数      0
# 705           历史交易登录设备登录结果为负数在1h内平均登录次数      0
# 668        上上段交易登录设备登录结果为正数在14_30d内登录次数      0
# 747            本次登录设备6_12h内登录其他用户次数结果为1      0
# 774           本次登录设备20min内登录其他用户次数结果为负数      0
# 775           本次登录设备30min内登录其他用户次数结果为负数      0
# 776              本次登录设备1h内登录其他用户次数结果为负数      0
# 777              本次登录设备2h内登录其他用户次数结果为负数      0
# 778            本次登录设备2_6h内登录其他用户次数结果为负数      0
# 779           本次登录设备6_12h内登录其他用户次数结果为负数      0
# 780          本次登录设备12h_1d内登录其他用户次数结果为负数      0
# 781            本次登录设备1_2d内登录其他用户次数结果为负数      0
# 782            本次登录设备2_7d内登录其他用户次数结果为负数      0
# 783           本次登录设备7_14d内登录其他用户次数结果为负数      0
# 784          本次登录设备14_30d内登录其他用户次数结果为负数      0
# 785          本次登录设备30_45d内登录其他用户次数结果为负数      0
# 786          本次登录设备45_60d内登录其他用户次数结果为负数      0
# 787              本次登录设备历史内登录其他用户次数结果为负数      0
# 788            本次登录设备3min内登录其他用户次数结果为正数      0
# 773           本次登录设备10min内登录其他用户次数结果为负数      0
# 772            本次登录设备3min内登录其他用户次数结果为负数      0
# 771              本次登录设备历史内登录其他用户次数结果为31      0
# 757           本次登录设备10min内登录其他用户次数结果为31      0
# 749             本次登录设备1_2d内登录其他用户次数结果为1      0
# 751            本次登录设备7_14d内登录其他用户次数结果为1      0
# 752           本次登录设备14_30d内登录其他用户次数结果为1      0
# 911                     10min内登录结果为负数次数      0
# 24                      3天内交易时间11-12点次数      0
# 756            本次登录设备3min内登录其他用户次数结果为31      0
# 759           本次登录设备30min内登录其他用户次数结果为31      0
# 907                     1d内登录不同IP数结果为正数      0
# 762            本次登录设备2_6h内登录其他用户次数结果为31      0
# 763           本次登录设备6_12h内登录其他用户次数结果为31      0
# 764          本次登录设备12h_1d内登录其他用户次数结果为31      0
# 766            本次登录设备2_7d内登录其他用户次数结果为31      0
# 767           本次登录设备7_14d内登录其他用户次数结果为31      0
# 768          本次登录设备14_30d内登录其他用户次数结果为31      0
# 789           本次登录设备10min内登录其他用户次数结果为正数      0
# 790           本次登录设备20min内登录其他用户次数结果为正数      0
# 791           本次登录设备30min内登录其他用户次数结果为正数      0
# 15                              3天内交易段数      0
# 895                     2h内登录不同IP数结果为31      0
# 19                          3天内交易最大间隔天数      0
# 18                       3天登录与交易的最大时间间隔      0
# 893                  10min内登录不同IP数结果为31      0
# 17                          3天内交易平均间隔天数      0
# 16                       3天登录与交易的平均时间间隔      0
# 842                 本次登录城市在14_30d内被登录次数      0
# 20                       3天登录与交易的最小时间间隔      0
# 879                 本次登录IP在14_30d内被登录次数      0
# 869                     6h内登录不同城市数结果为正数      0
# 856                  10min内登录不同城市数结果为31      0
# 857                  30min内登录不同城市数结果为31      0
# 867                  30min内登录不同城市数结果为正数      0
# 861                  10min内登录不同城市数结果为负数      0
# 898                  10min内登录不同IP数结果为负数      0
# 900                     2h内登录不同IP数结果为负数      0
# 792              本次登录设备1h内登录其他用户次数结果为正数      0
# 799           本次登录设备7_14d内登录其他用户次数结果为正数      0
# 793              本次登录设备2h内登录其他用户次数结果为正数      0
# 794            本次登录设备2_6h内登录其他用户次数结果为正数      0
# 795           本次登录设备6_12h内登录其他用户次数结果为正数      0
# 796          本次登录设备12h_1d内登录其他用户次数结果为正数      0
# 797            本次登录设备1_2d内登录其他用户次数结果为正数      0
# 798            本次登录设备2_7d内登录其他用户次数结果为正数      0
# 800          本次登录设备14_30d内登录其他用户次数结果为正数      0
# 21                          3天内交易最小间隔天数      0
# 801          本次登录设备30_45d内登录其他用户次数结果为正数      0
# 905                     2h内登录不同IP数结果为正数      0
# 23                       3天内交易时间4-10点次数      0
# 22                        3天内交易时间0-3点次数      0
# 904                  30min内登录不同IP数结果为正数      0
# 903                  10min内登录不同IP数结果为正数      0
# 748           本次登录设备12h_1d内登录其他用户次数结果为1      0
# 743            本次登录设备30min内登录其他用户次数结果为1      0
# 669        上上段交易登录设备登录结果为正数在30_45d内登录次数      0
# 741            本次登录设备10min内登录其他用户次数结果为1      0
# 688         历史交易登录设备登录结果为1在7_14d内平均登录次数      0
# 689        历史交易登录设备登录结果为1在14_30d内平均登录次数      0
# 690        历史交易登录设备登录结果为1在30_45d内平均登录次数      0
# 691        历史交易登录设备登录结果为31在10min内平均登录次数      0
# 692        历史交易登录设备登录结果为31在20min内平均登录次数      0
# 693        历史交易登录设备登录结果为31在30min内平均登录次数      0
# 694           历史交易登录设备登录结果为31在1h内平均登录次数      0
# 695         历史交易登录设备登录结果为31在1_2h内平均登录次数      0
# 696        历史交易登录设备登录结果为31在2h_1d内平均登录次数      0
# 697         历史交易登录设备登录结果为31在1_3d内平均登录次数      0
# 698         历史交易登录设备登录结果为31在3_7d内平均登录次数      0
# 699        历史交易登录设备登录结果为31在7_14d内平均登录次数      0
# 700       历史交易登录设备登录结果为31在14_30d内平均登录次数      0
# 701       历史交易登录设备登录结果为31在30_45d内平均登录次数      0
# 702        历史交易登录设备登录结果为负数在10min内平均登录次数      0
# 687          历史交易登录设备登录结果为1在3_7d内平均登录次数      0
# 686          历史交易登录设备登录结果为1在1_3d内平均登录次数      0
# 685         历史交易登录设备登录结果为1在2h_1d内平均登录次数      0
# 676                历史交易登录设备在3_7d内平均登录次数      0
# 670               历史交易登录设备在10min内平均登录次数      0
# 671               历史交易登录设备在30min内平均登录次数      0
# 672                  历史交易登录设备在1h内平均登录次数      0
# 673                历史交易登录设备在1_2h内平均登录次数      0
# 674               历史交易登录设备在2h_1d内平均登录次数      0
# 675                历史交易登录设备在1_3d内平均登录次数      0
# 677               历史交易登录设备在7_14d内平均登录次数      0
# 684          历史交易登录设备登录结果为1在1_2h内平均登录次数      0
# 678              历史交易登录设备在14_30d内平均登录次数      0
# 679              历史交易登录设备在30_45d内平均登录次数      0
# 680         历史交易登录设备登录结果为1在10min内平均登录次数      0
# 681         历史交易登录设备登录结果为1在20min内平均登录次数      0
# 682         历史交易登录设备登录结果为1在30min内平均登录次数      0
# 683            历史交易登录设备登录结果为1在1h内平均登录次数      0
# 703        历史交易登录设备登录结果为负数在20min内平均登录次数      0
# 704        历史交易登录设备登录结果为负数在30min内平均登录次数      0
# 706         历史交易登录设备登录结果为负数在1_2h内平均登录次数      0
# 732               本次登录设备12h_1d内登录其他用户次数      0
# 922                     90min内登录结果为正数次数      0
# 726                本次登录设备20min内登录其他用户次数      0
# 727                本次登录设备30min内登录其他用户次数      0
# 728                   本次登录设备1h内登录其他用户次数      0
# 730                 本次登录设备2_6h内登录其他用户次数      0
# 731                本次登录设备6_12h内登录其他用户次数      0
# 733                 本次登录设备1_2d内登录其他用户次数      0
# 724                 本次登录设备3min内登录其他用户次数      0
# 734                 本次登录设备2_7d内登录其他用户次数      0
# 735                本次登录设备7_14d内登录其他用户次数      0
# 736               本次登录设备14_30d内登录其他用户次数      0
# 737               本次登录设备30_45d内登录其他用户次数      0
# 739                   本次登录设备历史内登录其他用户次数      0
# 740             本次登录设备3min内登录其他用户次数结果为1      0
# 725                本次登录设备10min内登录其他用户次数      0
# 723       历史交易登录设备登录结果为正数在30_45d内平均登录次数      0
# 707        历史交易登录设备登录结果为负数在2h_1d内平均登录次数      0
# 714        历史交易登录设备登录结果为正数在20min内平均登录次数      0
# 708         历史交易登录设备登录结果为负数在1_3d内平均登录次数      0
# 709         历史交易登录设备登录结果为负数在3_7d内平均登录次数      0
# 710        历史交易登录设备登录结果为负数在7_14d内平均登录次数      0
# 711       历史交易登录设备登录结果为负数在14_30d内平均登录次数      0
# 712       历史交易登录设备登录结果为负数在30_45d内平均登录次数      0
# 713        历史交易登录设备登录结果为正数在10min内平均登录次数      0
# 715        历史交易登录设备登录结果为正数在30min内平均登录次数      0
# 722       历史交易登录设备登录结果为正数在14_30d内平均登录次数      0
# 716           历史交易登录设备登录结果为正数在1h内平均登录次数      0
# 717         历史交易登录设备登录结果为正数在1_2h内平均登录次数      0
# 718        历史交易登录设备登录结果为正数在2h_1d内平均登录次数      0
# 719         历史交易登录设备登录结果为正数在1_3d内平均登录次数      0
# 720         历史交易登录设备登录结果为正数在3_7d内平均登录次数      0
# 721        历史交易登录设备登录结果为正数在7_14d内平均登录次数      0
# 765            本次登录设备1_2d内登录其他用户次数结果为31      0
# 68                          3_14天内交易为周日      0
# 570                上段交易登录设备在14_30d内登录次数      0
# 228              20min内登录结果为其他登录来源为16次数      0
# 230               20min内登录结果为其他登录来源为3次数      0
# 231              20min内登录结果为其他登录来源为12次数      0
# 235                  1h内登录结果为1登录来源为11次数      0
# 236                  1h内登录结果为1登录来源为21次数      0
# 237                   1h内登录结果为1登录来源为5次数      0
# 238                   1h内登录结果为1登录来源为8次数      0
# 239                  1h内登录结果为1登录来源为16次数      0
# 240                  1h内登录结果为1登录来源为18次数      0
# 241                   1h内登录结果为1登录来源为3次数      0
# 242                  1h内登录结果为1登录来源为12次数      0
# 243                 1h内登录结果为31登录来源为10次数      0
# 246                 1h内登录结果为31登录来源为11次数      0
# 247                 1h内登录结果为31登录来源为21次数      0
# 248                  1h内登录结果为31登录来源为5次数      0
# 249                  1h内登录结果为31登录来源为8次数      0
# 250                 1h内登录结果为31登录来源为16次数      0
# 251                 1h内登录结果为31登录来源为18次数      0
# 252                  1h内登录结果为31登录来源为3次数      0
# 253                 1h内登录结果为31登录来源为12次数      0
# 254                 1h内登录结果为其他登录来源为10次数      0
# 255                  1h内登录结果为其他登录来源为1次数      0
# 229              20min内登录结果为其他登录来源为18次数      0
# 227               20min内登录结果为其他登录来源为8次数      0
# 314           上段交易20min内登录结果为31登录来源为5次数      0
# 226               20min内登录结果为其他登录来源为5次数      0
# 203               20min内登录结果为1登录来源为21次数      0
# 204                20min内登录结果为1登录来源为5次数      0
# 205                20min内登录结果为1登录来源为8次数      0
# 206               20min内登录结果为1登录来源为16次数      0
# 207               20min内登录结果为1登录来源为18次数      0
# 208                20min内登录结果为1登录来源为3次数      0
# 209               20min内登录结果为1登录来源为12次数      0
# 210              20min内登录结果为31登录来源为10次数      0
# 213              20min内登录结果为31登录来源为11次数      0
# 214              20min内登录结果为31登录来源为21次数      0
# 215               20min内登录结果为31登录来源为5次数      0
# 216               20min内登录结果为31登录来源为8次数      0
# 217              20min内登录结果为31登录来源为16次数      0
# 218              20min内登录结果为31登录来源为18次数      0
# 219               20min内登录结果为31登录来源为3次数      0
# 220              20min内登录结果为31登录来源为12次数      0
# 221              20min内登录结果为其他登录来源为10次数      0
# 222               20min内登录结果为其他登录来源为1次数      0
# 223               20min内登录结果为其他登录来源为2次数      0
# 224              20min内登录结果为其他登录来源为11次数      0
# 225              20min内登录结果为其他登录来源为21次数      0
# 256                  1h内登录结果为其他登录来源为2次数      0
# 257                 1h内登录结果为其他登录来源为11次数      0
# 258                 1h内登录结果为其他登录来源为21次数      0
# 259                  1h内登录结果为其他登录来源为5次数      0
# 289                  2h内登录结果为其他登录来源为2次数      0
# 290                 2h内登录结果为其他登录来源为11次数      0
# 291                 2h内登录结果为其他登录来源为21次数      0
# 292                  2h内登录结果为其他登录来源为5次数      0
# 293                  2h内登录结果为其他登录来源为8次数      0
# 294                 2h内登录结果为其他登录来源为16次数      0
# 295                 2h内登录结果为其他登录来源为18次数      0
# 296                  2h内登录结果为其他登录来源为3次数      0
# 297                 2h内登录结果为其他登录来源为12次数      0
# 301           上段交易20min内登录结果为1登录来源为11次数      0
# 302           上段交易20min内登录结果为1登录来源为21次数      0
# 303            上段交易20min内登录结果为1登录来源为5次数      0
# 304            上段交易20min内登录结果为1登录来源为8次数      0
# 305           上段交易20min内登录结果为1登录来源为16次数      0
# 306           上段交易20min内登录结果为1登录来源为18次数      0
# 307            上段交易20min内登录结果为1登录来源为3次数      0
# 308           上段交易20min内登录结果为1登录来源为12次数      0
# 309          上段交易20min内登录结果为31登录来源为10次数      0
# 310           上段交易20min内登录结果为31登录来源为1次数      0
# 311           上段交易20min内登录结果为31登录来源为2次数      0
# 312          上段交易20min内登录结果为31登录来源为11次数      0
# 288                  2h内登录结果为其他登录来源为1次数      0
# 287                 2h内登录结果为其他登录来源为10次数      0
# 286                 2h内登录结果为31登录来源为12次数      0
# 272                  2h内登录结果为1登录来源为16次数      0
# 260                  1h内登录结果为其他登录来源为8次数      0
# 261                 1h内登录结果为其他登录来源为16次数      0
# 262                 1h内登录结果为其他登录来源为18次数      0
# 263                  1h内登录结果为其他登录来源为3次数      0
# 264                 1h内登录结果为其他登录来源为12次数      0
# 268                  2h内登录结果为1登录来源为11次数      0
# 269                  2h内登录结果为1登录来源为21次数      0
# 270                   2h内登录结果为1登录来源为5次数      0
# 271                   2h内登录结果为1登录来源为8次数      0
# 273                  2h内登录结果为1登录来源为18次数      0
# 285                  2h内登录结果为31登录来源为3次数      0
# 274                   2h内登录结果为1登录来源为3次数      0
# 275                  2h内登录结果为1登录来源为12次数      0
# 276                 2h内登录结果为31登录来源为10次数      0
# 279                 2h内登录结果为31登录来源为11次数      0
# 280                 2h内登录结果为31登录来源为21次数      0
# 281                  2h内登录结果为31登录来源为5次数      0
# 282                  2h内登录结果为31登录来源为8次数      0
# 283                 2h内登录结果为31登录来源为16次数      0
# 284                 2h内登录结果为31登录来源为18次数      0
# 202               20min内登录结果为1登录来源为11次数      0
# 35                             3天内交易为周二      0
# 198                           本次登录来源为12      0
# 118                        30_60天内交易为周四      0
# 96                          30_60天内交易段数      0
# 97                   30_60天登录与交易的平均时间间隔      0
# 98                      30_60天内交易平均间隔天数      0
# 99                   30_60天登录与交易的最大时间间隔      0
# 100                     30_60天内交易最大间隔天数      0
# 101                  30_60天登录与交易的最小时间间隔      0
# 102                     30_60天内交易最小间隔天数      0
# 103                   30_60天内交易时间0-3点次数      0
# 104                  30_60天内交易时间4-10点次数      0
# 105                 30_60天内交易时间11-12点次数      0
# 106                 30_60天内交易时间13-17点次数      0
# 107                 30_60天内交易时间18-20点次数      0
# 108                 30_60天内交易时间21-23点次数      0
# 109                   30_60天内交易时间0-3点占比      0
# 110                  30_60天内交易时间4-10点占比      0
# 111                 30_60天内交易时间11-12点占比      0
# 112                 30_60天内交易时间13-17点占比      0
# 113                 30_60天内交易时间18-20点占比      0
# 114                 30_60天内交易时间21-23点占比      0
# 115                        30_60天内交易为周一      0
# 116                        30_60天内交易为周二      0
# 45                       3_14天内交易平均间隔天数      0
# 46                    3_14天登录与交易的最大时间间隔      0
# 47                       3_14天内交易最大间隔天数      0
# 59                   3_14天内交易时间13-17点占比      0
# 70                    3_14天内交易是否为节假日前一天      0
# 67                          3_14天内交易为周六      0
# 66                          3_14天内交易为周五      0
# 65                          3_14天内交易为周四      0
# 64                          3_14天内交易为周三      0
# 63                          3_14天内交易为周二      0
# 62                          3_14天内交易为周一      0
# 61                   3_14天内交易时间21-23点占比      0
# 60                   3_14天内交易时间18-20点占比      0
# 58                   3_14天内交易时间11-12点占比      0
# 48                    3_14天登录与交易的最小时间间隔      0
# 57                    3_14天内交易时间4-10点占比      0
# 56                     3_14天内交易时间0-3点占比      0
# 55                   3_14天内交易时间21-23点次数      0
# 54                   3_14天内交易时间18-20点次数      0
# 53                   3_14天内交易时间13-17点次数      0
# 52                   3_14天内交易时间11-12点次数      0
# 51                    3_14天内交易时间4-10点次数      0
# 50                     3_14天内交易时间0-3点次数      0
# 49                       3_14天内交易最小间隔天数      0
# 117                        30_60天内交易为周三      0
# 119                        30_60天内交易为周五      0
# 197                            本次登录来源为3      0
# 120                        30_60天内交易为周六      0
# 145                            历史内交易为周三      0
# 146                            历史内交易为周四      0
# 147                            历史内交易为周五      0
# 148                            历史内交易为周六      0
# 149                            历史内交易为周日      0
# 150                         历史内交易是否为节假日      0
# 151                      历史内交易是否为节假日前一天      0
# 44                    3_14天登录与交易的平均时间间隔      0
# 43                           3_14天内交易段数      0
# 42                       3天内交易是否为节假日前一天      0
# 41                          3天内交易是否为节假日      0
# 40                             3天内交易为周日      0
# 39                             3天内交易为周六      0
# 38                             3天内交易为周五      0
# 37                             3天内交易为周四      0
# 36                             3天内交易为周三      0
# 191                           本次登录来源为11      0
# 192                           本次登录来源为21      0
# 193                            本次登录来源为5      0
# 194                            本次登录来源为8      0
# 196                           本次登录来源为18      0
# 144                            历史内交易为周二      0
# 143                            历史内交易为周一      0
# 142                     历史内交易时间21-23点占比      0
# 130                         历史内交易最小间隔天数      0
# 121                        30_60天内交易为周日      0
# 122                     30_60天内交易是否为节假日      0
# 123                  30_60天内交易是否为节假日前一天      0
# 124                             历史内交易段数      0
# 125                      历史登录与交易的平均时间间隔      0
# 126                         历史内交易平均间隔天数      0
# 127                      历史登录与交易的最大时间间隔      0
# 128                         历史内交易最大间隔天数      0
# 129                      历史登录与交易的最小时间间隔      0
# 131                       历史内交易时间0-3点次数      0
# 141                     历史内交易时间18-20点占比      0
# 132                      历史内交易时间4-10点次数      0
# 133                     历史内交易时间11-12点次数      0
# 134                     历史内交易时间13-17点次数      0
# 135                     历史内交易时间18-20点次数      0
# 136                     历史内交易时间21-23点次数      0
# 137                       历史内交易时间0-3点占比      0
# 138                      历史内交易时间4-10点占比      0
# 139                     历史内交易时间11-12点占比      0
# 140                     历史内交易时间13-17点占比      0
# 313          上段交易20min内登录结果为31登录来源为21次数      0
# 315           上段交易20min内登录结果为31登录来源为8次数      0
# 561               本次登录设备登录结果为正数在历史内登录次数      0
# 449            上上段交易1h内登录结果为31登录来源为18次数      0
# 451            上上段交易1h内登录结果为31登录来源为12次数      0
# 452            上上段交易1h内登录结果为其他登录来源为10次数      0
# 453             上上段交易1h内登录结果为其他登录来源为1次数      0
# 454             上上段交易1h内登录结果为其他登录来源为2次数      0
# 455            上上段交易1h内登录结果为其他登录来源为11次数      0
# 456            上上段交易1h内登录结果为其他登录来源为21次数      0
# 457             上上段交易1h内登录结果为其他登录来源为5次数      0
# 458             上上段交易1h内登录结果为其他登录来源为8次数      0
# 459            上上段交易1h内登录结果为其他登录来源为16次数      0
# 460            上上段交易1h内登录结果为其他登录来源为18次数      0
# 461             上上段交易1h内登录结果为其他登录来源为3次数      0
# 462            上上段交易1h内登录结果为其他登录来源为12次数      0
# 466             上上段交易2h内登录结果为1登录来源为11次数      0
# 467             上上段交易2h内登录结果为1登录来源为21次数      0
# 468              上上段交易2h内登录结果为1登录来源为5次数      0
# 469              上上段交易2h内登录结果为1登录来源为8次数      0
# 470             上上段交易2h内登录结果为1登录来源为16次数      0
# 471             上上段交易2h内登录结果为1登录来源为18次数      0
# 472              上上段交易2h内登录结果为1登录来源为3次数      0
# 473             上上段交易2h内登录结果为1登录来源为12次数      0
# 474            上上段交易2h内登录结果为31登录来源为10次数      0
# 450             上上段交易1h内登录结果为31登录来源为3次数      0
# 448            上上段交易1h内登录结果为31登录来源为16次数      0
# 316          上段交易20min内登录结果为31登录来源为16次数      0
# 447             上上段交易1h内登录结果为31登录来源为8次数      0
# 424          上上段交易20min内登录结果为其他登录来源为5次数      0
# 425          上上段交易20min内登录结果为其他登录来源为8次数      0
# 426         上上段交易20min内登录结果为其他登录来源为16次数      0
# 427         上上段交易20min内登录结果为其他登录来源为18次数      0
# 428          上上段交易20min内登录结果为其他登录来源为3次数      0
# 429         上上段交易20min内登录结果为其他登录来源为12次数      0
# 430             上上段交易1h内登录结果为1登录来源为10次数      0
# 433             上上段交易1h内登录结果为1登录来源为11次数      0
# 434             上上段交易1h内登录结果为1登录来源为21次数      0
# 435              上上段交易1h内登录结果为1登录来源为5次数      0
# 436              上上段交易1h内登录结果为1登录来源为8次数      0
# 437             上上段交易1h内登录结果为1登录来源为16次数      0
# 438             上上段交易1h内登录结果为1登录来源为18次数      0
# 439              上上段交易1h内登录结果为1登录来源为3次数      0
# 440             上上段交易1h内登录结果为1登录来源为12次数      0
# 441            上上段交易1h内登录结果为31登录来源为10次数      0
# 442             上上段交易1h内登录结果为31登录来源为1次数      0
# 443             上上段交易1h内登录结果为31登录来源为2次数      0
# 444            上上段交易1h内登录结果为31登录来源为11次数      0
# 445            上上段交易1h内登录结果为31登录来源为21次数      0
# 446             上上段交易1h内登录结果为31登录来源为5次数      0
# 475             上上段交易2h内登录结果为31登录来源为1次数      0
# 477            上上段交易2h内登录结果为31登录来源为11次数      0
# 478            上上段交易2h内登录结果为31登录来源为21次数      0
# 479             上上段交易2h内登录结果为31登录来源为5次数      0
# 519            本次登录设备登录结果为1在14_30d内登录次数      0
# 28                        3天内交易时间0-3点占比      0
# 27                      3天内交易时间21-23点次数      0
# 530             本次登录设备登录结果为31在3_7d内登录次数      0
# 531            本次登录设备登录结果为31在7_14d内登录次数      0
# 532           本次登录设备登录结果为31在14_30d内登录次数      0
# 26                      3天内交易时间18-20点次数      0
# 539               本次登录设备登录结果为负数在1h内登录次数      0
# 540             本次登录设备登录结果为负数在1_2h内登录次数      0
# 542             本次登录设备登录结果为负数在1_3d内登录次数      0
# 543             本次登录设备登录结果为负数在3_7d内登录次数      0
# 544            本次登录设备登录结果为负数在7_14d内登录次数      0
# 545           本次登录设备登录结果为负数在14_30d内登录次数      0
# 548               本次登录设备登录结果为负数在历史内登录次数      0
# 553             本次登录设备登录结果为正数在1_2h内登录次数      0
# 554            本次登录设备登录结果为正数在2h_1d内登录次数      0
# 555             本次登录设备登录结果为正数在1_3d内登录次数      0
# 556             本次登录设备登录结果为正数在3_7d内登录次数      0
# 557            本次登录设备登录结果为正数在7_14d内登录次数      0
# 558           本次登录设备登录结果为正数在14_30d内登录次数      0
# 25                      3天内交易时间13-17点次数      0
# 69                       3_14天内交易是否为节假日      0
# 512             本次登录设备登录结果为1在30min内登录次数      0
# 29                       3天内交易时间4-10点占比      0
# 490             上上段交易2h内登录结果为其他登录来源为5次数      0
# 480             上上段交易2h内登录结果为31登录来源为8次数      0
# 481            上上段交易2h内登录结果为31登录来源为16次数      0
# 482            上上段交易2h内登录结果为31登录来源为18次数      0
# 484            上上段交易2h内登录结果为31登录来源为12次数      0
# 485            上上段交易2h内登录结果为其他登录来源为10次数      0
# 486             上上段交易2h内登录结果为其他登录来源为1次数      0
# 487             上上段交易2h内登录结果为其他登录来源为2次数      0
# 488            上上段交易2h内登录结果为其他登录来源为11次数      0
# 489            上上段交易2h内登录结果为其他登录来源为21次数      0
# 491             上上段交易2h内登录结果为其他登录来源为8次数      0
# 30                      3天内交易时间11-12点占比      0
# 492            上上段交易2h内登录结果为其他登录来源为16次数      0
# 493            上上段交易2h内登录结果为其他登录来源为18次数      0
# 494             上上段交易2h内登录结果为其他登录来源为3次数      0
# 495            上上段交易2h内登录结果为其他登录来源为12次数      0
# 34                             3天内交易为周一      0
# 33                      3天内交易时间21-23点占比      0
# 32                      3天内交易时间18-20点占比      0
# 506                  本次登录设备在14_30d内登录次数      0
# 31                      3天内交易时间13-17点占比      0
# 423         上上段交易20min内登录结果为其他登录来源为21次数      0
# 422         上上段交易20min内登录结果为其他登录来源为11次数      0
# 421          上上段交易20min内登录结果为其他登录来源为2次数      0
# 370               上段交易2h内登录结果为1登录来源为8次数      0
# 345             上段交易1h内登录结果为31登录来源为11次数      0
# 346             上段交易1h内登录结果为31登录来源为21次数      0
# 347              上段交易1h内登录结果为31登录来源为5次数      0
# 348              上段交易1h内登录结果为31登录来源为8次数      0
# 349             上段交易1h内登录结果为31登录来源为16次数      0
# 350             上段交易1h内登录结果为31登录来源为18次数      0
# 351              上段交易1h内登录结果为31登录来源为3次数      0
# 352             上段交易1h内登录结果为31登录来源为12次数      0
# 353             上段交易1h内登录结果为其他登录来源为10次数      0
# 354              上段交易1h内登录结果为其他登录来源为1次数      0
# 355              上段交易1h内登录结果为其他登录来源为2次数      0
# 356             上段交易1h内登录结果为其他登录来源为11次数      0
# 357             上段交易1h内登录结果为其他登录来源为21次数      0
# 358              上段交易1h内登录结果为其他登录来源为5次数      0
# 359              上段交易1h内登录结果为其他登录来源为8次数      0
# 360             上段交易1h内登录结果为其他登录来源为16次数      0
# 361             上段交易1h内登录结果为其他登录来源为18次数      0
# 362              上段交易1h内登录结果为其他登录来源为3次数      0
# 363             上段交易1h内登录结果为其他登录来源为12次数      0
# 367              上段交易2h内登录结果为1登录来源为11次数      0
# 368              上段交易2h内登录结果为1登录来源为21次数      0
# 344              上段交易1h内登录结果为31登录来源为2次数      0
# 342             上段交易1h内登录结果为31登录来源为10次数      0
# 341              上段交易1h内登录结果为1登录来源为12次数      0
# 326           上段交易20min内登录结果为其他登录来源为8次数      0
# 317          上段交易20min内登录结果为31登录来源为18次数      0
# 318           上段交易20min内登录结果为31登录来源为3次数      0
# 319          上段交易20min内登录结果为31登录来源为12次数      0
# 320          上段交易20min内登录结果为其他登录来源为10次数      0
# 321           上段交易20min内登录结果为其他登录来源为1次数      0
# 322           上段交易20min内登录结果为其他登录来源为2次数      0
# 323          上段交易20min内登录结果为其他登录来源为11次数      0
# 324          上段交易20min内登录结果为其他登录来源为21次数      0
# 325           上段交易20min内登录结果为其他登录来源为5次数      0
# 327          上段交易20min内登录结果为其他登录来源为16次数      0
# 340               上段交易1h内登录结果为1登录来源为3次数      0
# 328          上段交易20min内登录结果为其他登录来源为18次数      0
# 329           上段交易20min内登录结果为其他登录来源为3次数      0
# 330          上段交易20min内登录结果为其他登录来源为12次数      0
# 334              上段交易1h内登录结果为1登录来源为11次数      0
# 335              上段交易1h内登录结果为1登录来源为21次数      0
# 336               上段交易1h内登录结果为1登录来源为5次数      0
# 337               上段交易1h内登录结果为1登录来源为8次数      0
# 338              上段交易1h内登录结果为1登录来源为16次数      0
# 339              上段交易1h内登录结果为1登录来源为18次数      0
# 369               上段交易2h内登录结果为1登录来源为5次数      0
# 371              上段交易2h内登录结果为1登录来源为16次数      0
# 420          上上段交易20min内登录结果为其他登录来源为1次数      0
# 372              上段交易2h内登录结果为1登录来源为18次数      0
# 399           上上段交易20min内登录结果为1登录来源为2次数      0
# 400          上上段交易20min内登录结果为1登录来源为11次数      0
# 401          上上段交易20min内登录结果为1登录来源为21次数      0
# 402           上上段交易20min内登录结果为1登录来源为5次数      0
# 403           上上段交易20min内登录结果为1登录来源为8次数      0
# 404          上上段交易20min内登录结果为1登录来源为16次数      0
# 405          上上段交易20min内登录结果为1登录来源为18次数      0
# 406           上上段交易20min内登录结果为1登录来源为3次数      0
# 407          上上段交易20min内登录结果为1登录来源为12次数      0
# 408         上上段交易20min内登录结果为31登录来源为10次数      0
# 409          上上段交易20min内登录结果为31登录来源为1次数      0
# 410          上上段交易20min内登录结果为31登录来源为2次数      0
# 411         上上段交易20min内登录结果为31登录来源为11次数      0
# 412         上上段交易20min内登录结果为31登录来源为21次数      0
# 413          上上段交易20min内登录结果为31登录来源为5次数      0
# 414          上上段交易20min内登录结果为31登录来源为8次数      0
# 415         上上段交易20min内登录结果为31登录来源为16次数      0
# 416         上上段交易20min内登录结果为31登录来源为18次数      0
# 417          上上段交易20min内登录结果为31登录来源为3次数      0
# 418         上上段交易20min内登录结果为31登录来源为12次数      0
# 419         上上段交易20min内登录结果为其他登录来源为10次数      0
# 398           上上段交易20min内登录结果为1登录来源为1次数      0
# 397          上上段交易20min内登录结果为1登录来源为10次数      0
# 396             上段交易2h内登录结果为其他登录来源为12次数      0
# 384              上段交易2h内登录结果为31登录来源为3次数      0
# 373               上段交易2h内登录结果为1登录来源为3次数      0
# 374              上段交易2h内登录结果为1登录来源为12次数      0
# 375             上段交易2h内登录结果为31登录来源为10次数      0
# 378             上段交易2h内登录结果为31登录来源为11次数      0
# 379             上段交易2h内登录结果为31登录来源为21次数      0
# 380              上段交易2h内登录结果为31登录来源为5次数      0
# 381              上段交易2h内登录结果为31登录来源为8次数      0
# 382             上段交易2h内登录结果为31登录来源为16次数      0
# 383             上段交易2h内登录结果为31登录来源为18次数      0
# 385             上段交易2h内登录结果为31登录来源为12次数      0
# 395              上段交易2h内登录结果为其他登录来源为3次数      0
# 386             上段交易2h内登录结果为其他登录来源为10次数      0
# 387              上段交易2h内登录结果为其他登录来源为1次数      0
# 388              上段交易2h内登录结果为其他登录来源为2次数      0
# 389             上段交易2h内登录结果为其他登录来源为11次数      0
# 390             上段交易2h内登录结果为其他登录来源为21次数      0
# 391              上段交易2h内登录结果为其他登录来源为5次数      0
# 392              上段交易2h内登录结果为其他登录来源为8次数      0
# 393             上段交易2h内登录结果为其他登录来源为16次数      0
# 394             上段交易2h内登录结果为其他登录来源为18次数      0
# 483             上上段交易2h内登录结果为31登录来源为3次数      0

# %%
clf4a = lgb.LGBMClassifier(boosting_type='dart', learning_rate=0.14, max_depth=18, n_estimators=2050, colsample_bytree=0.82, 
                          min_split_gain=1.2, max_bin=730, reg_lambda=0.9, is_unbalance=True, random_state=400, subsample=0.9)
clf4a.fit(X_train[s_column_2], X_train.pesudo_label1, eval_metric=eval_fbeta)
gc.collect()
# Out:
# 25

# %%
feature_df4a = pd.DataFrame()
feature_df4a['feature'] = s_column_2
feature_df4a['score'] = clf4.feature_importance()
feature_df4a.sort_values(['score'], ascending=False).reset_index(drop=True)
# Out:
# /Users/admin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:75: DeprecationWarning: Function feature_importance is deprecated; Use attribute feature_importances_ instead.
#   warnings.warn(msg, category=DeprecationWarning)
#                                 feature  score
# 0                   本次登录城市在45_60d内被登录次数   2198
# 1              本次登录设备登录结果为1在45_60d内登录次数   1126
# 2                   本次登录城市在30_45d内被登录次数   1013
# 3                       14_30天内交易最大间隔天数    847
# 4                   本次登录IP在45_60d内被登录次数    799
# 5                    本次登录设备在45_60d内登录次数    769
# 6                       14_30天内交易最小间隔天数    659
# 7             本次登录设备45_60d内登录其他用户次数结果为1    622
# 8                     14_30天内交易时间0-3点占比    604
# 9                            本次登录类型是否为3    566
# 10                   1d内登录设备中新设备数量且结果为1    485
# 11                          14_30天内交易段数    476
# 12                  14_30天内交易时间13-17点次数    457
# 13                             本次登录来源为2    454
# 14                         用户全局是否只有本段交易    441
# 15                   6h内登录设备中新设备数量且结果为1    430
# 16                      14_30天内交易是否为节假日    414
# 17                      本次登录城市在历史内被登录次数    407
# 18                         14_30天内交易为周六    407
# 19             本次登录设备登录结果为1在30_45d内登录次数    389
# 20                   本次登录设备在30_45d内登录次数    385
# 21                         14_30天内交易为周二    380
# 22            本次登录设备登录结果为31在45_60d内登录次数    362
# 23                  14_30天内交易时间13-17点占比    354
# 24                          本次登录设备是否新设备    353
# 25                           本次登录类型是否为1    352
# 26                         14_30天内交易为周一    333
# 27                     用户全局行为是否全在前后24h内    329
# 28                         14_30天内交易为周四    309
# 29                        本次登录设备是否成功新设备    303
# 30                           1d内登录不同IP数    298
# 31                             本次登录来源为1    294
# 32                      14_30天内交易平均间隔天数    280
# 33                      上上段交易登录与交易的时间间隔    266
# 34                         14_30天内交易为周五    264
# 35                  14_30天内交易时间11-12点占比    247
# 36                  14_30天内交易时间21-23点占比    237
# 37                       1d内登录不同设备数结果为1    236
# 38                    本次登录城市在1_3d内被登录次数    222
# 39                   本次登录城市在2h_1d内被登录次数    218
# 40                   本次登录城市在7_14d内被登录次数    216
# 41                   14_30天内交易时间4-10点占比    215
# 42                  14_30天内交易时间18-20点占比    213
# 43                      1d内登录不同设备数结果为负数    202
# 44                          本次设备是交易设备概率    201
# 45                  14_30天内交易时间21-23点次数    199
# 46                           1d内登录不同设备数    195
# 47                      1d内登录不同设备数结果为31    191
# 48                           6h内登录不同设备数    189
# 49                   14_30天内交易时间4-10点次数    187
# 50                              今年第几段交易    183
# 51                        上段交易内交易时间0-3点    169
# 52                            本次登录来源为10    154
# 53                         14_30天内交易为周三    153
# 54            本次登录设备登录结果为正数在45_60d内登录次数    148
# 55                         14_30天内交易为周日    145
# 56                 20min内登录结果为1登录来源为1次数    145
# 57                    本次登录IP在1_3d内被登录次数    141
# 58                             是否今年初次交易    139
# 59                  14_30天内交易时间11-12点次数    139
# 60                   14_30天内交易是否为节假日前一天    137
# 61                           1d内登录不同城市数    136
# 62                       本次登录设备在历史内登录次数    124
# 63                  本次登录IP在30_45d内被登录次数    119
# 64                       6h内登录不同设备数结果为1    116
# 65                    本次登录城市在3_7d内被登录次数    113
# 66                    本次登录设备在2h_1d内登录次数    112
# 67                           本段交易时间0-3点    112
# 68           本次登录设备45_60d内登录其他用户次数结果为31    111
# 69                           上段交易内交易为周二    109
# 70                 本次登录设备登录结果为1在历史内登录次数    109
# 71                         本段交易时间11-12点    106
# 72                           上段交易内交易为周三    101
# 73                              本段交易为周日     99
# 74                 上段交易登录设备在30_45d内登录次数     94
# 75                           本次登录是否为新城市     92
# 76                    2h内登录结果为1登录来源为1次数     87
# 77                  上段交易登录设备在2h_1d内登录次数     87
# 78                10min内登录设备中新设备数量且结果为1     87
# 79                   2h内登录设备中新设备数量且结果为1     86
# 80                  上段交易登录设备在7_14d内登录次数     86
# 81                      上段交易内交易时间13-17点     85
# 82            本次登录设备登录结果为正数在30_45d内登录次数     83
# 83                 本次登录IP在0_30min内被登录次数     83
# 84                      90min内登录结果为31次数     83
# 85                      6h内登录不同设备数结果为31     81
# 86               本次登录设备登录结果为1在1_3d内登录次数     77
# 87               上段交易2h内登录结果为1登录来源为10次数     75
# 88              本次登录设备登录结果为1在7_14d内登录次数     74
# 89            上段交易登录设备登录结果为1在10min内登录次数     74
# 90            本次登录设备登录结果为负数在45_60d内登录次数     73
# 91                   上段交易登录设备在1_3d内登录次数     73
# 92                           本次登录类型是否为2     69
# 93                   本次登录IP在2h_1d内被登录次数     69
# 94                     上段交易登录设备在1h内登录次数     69
# 95             本次登录设备登录结果为负数在20min内登录次数     67
# 96                      120min内登录结果为1次数     65
# 97                 本次登录城市在0_30min内被登录次数     65
# 98                              本段交易为周三     65
# 99                   上段交易登录设备在3_7d内登录次数     65
# 100                   14_30天内交易时间0-3点次数     63
# 101                         上上段交易内交易为周日     62
# 102                       10min内登录不同IP数     62
# 103                             本段交易为周六     59
# 104               上段交易2h内登录结果为1登录来源为1次数     58
# 105                    本次登录设备在1_3d内登录次数     58
# 106               本次登录设备历史内登录其他用户次数结果为1     56
# 107                      本次登录设备在1h内登录次数     56
# 108                     6h内登录不同IP数结果为31     55
# 109                      1d内登录不同IP数结果为1     54
# 110                          6h内登录不同城市数     53
# 111                          6h内登录不同IP数     53
# 112               本次登录设备2h内登录其他用户次数结果为1     53
# 113                本次登录设备登录结果为1在1h内登录次数     52
# 114                  本次登录IP在7_14d内被登录次数     52
# 115                          上段交易内交易为周四     52
# 116                   本次登录设备在10min内登录次数     50
# 117               上上段交易登录设备在30_45d内登录次数     50
# 118                      90min内登录结果为1次数     50
# 119           本次登录设备30_45d内登录其他用户次数结果为1     50
# 120                      上段交易内交易时间4-10点     49
# 121                     1d内登录不同城市数结果为负数     48
# 122               本次登录城市在30min_1h内被登录次数     48
# 123                 14_30天内交易时间18-20点次数     47
# 124                20min内登录结果为1登录来源为2次数     47
# 125                       上段交易内交易是否为节假日     46
# 126                   1h内登录结果为1登录来源为1次数     45
# 127                     本次登录IP在历史内被登录次数     45
# 128                      20min内登录结果为1次数     44
# 129                       10min内登录不同城市数     44
# 130            本次登录设备登录结果为31在10min内登录次数     44
# 131                    上段交易内交易是否为节假日前一天     43
# 132                      10min内登录结果为1次数     43
# 133                          本次登录是否为新IP     42
# 134                     2h内登录不同设备数结果为31     41
# 135                      1d内登录不同城市数结果为1     41
# 136                          上段交易内交易为周一     41
# 137                   本次登录设备在7_14d内登录次数     40
# 138                    120min内登录结果为31次数     39
# 139                   2h内登录结果为1登录来源为2次数     39
# 140                      上上段交易内交易时间0-3点     39
# 141                     上上段交易内交易时间4-10点     39
# 142             本次登录设备登录结果为1在2h_1d内登录次数     39
# 143         上上段交易登录设备登录结果为1在30_45d内登录次数     39
# 144                     上段交易内交易时间21-23点     39
# 145          上段交易登录设备登录结果为1在30_45d内登录次数     38
# 146             上段交易登录设备登录结果为31在1h内登录次数     37
# 147                             本段交易为周一     36
# 148                   10min内登录不同IP数结果为1     35
# 149                        本段交易时间13-17点     34
# 150                         上上段交易内交易为周三     34
# 151                     20min内登录结果为负数次数     34
# 152                     1d内登录不同设备数结果为正数     33
# 153                     45min内登录结果为31次数     33
# 154                          2h内登录不同城市数     33
# 155             本次登录设备登录结果为1在10min内登录次数     32
# 156                   本次登录城市在1_2h内被登录次数     32
# 157                          2h内登录不同IP数     31
# 158                      2h内登录不同设备数结果为1     30
# 159               本次登录设备登录结果为31在历史内登录次数     29
# 160                   上上段交易内交易是否为节假日前一天     26
# 161                          上段交易内交易为周日     25
# 162                       本段交易是否为节假日前一天     25
# 163                           本次登录来源为16     24
# 164                     上段交易内交易时间11-12点     24
# 165                       10min内登录不同设备数     24
# 166                     20min内登录结果为31次数     24
# 167          上段交易登录设备登录结果为31在10min内登录次数     23
# 168                   1h内登录结果为1登录来源为2次数     23
# 169                     1d内登录不同城市数结果为31     23
# 170                       30min内登录不同设备数     23
# 171               30min内登录设备中新设备数量且结果为1     22
# 172         上段交易登录设备登录结果为正数在30_45d内登录次数     22
# 173                          上段交易内交易为周五     22
# 174            本次登录设备登录结果为31在2h_1d内登录次数     22
# 175           本次登录设备登录结果为31在30_45d内登录次数     22
# 176                             本段交易为周五     22
# 177            上段交易登录设备登录结果为1在1_3d内登录次数     22
# 178                  本次登录设备30min内连接IP次数     22
# 179               20min内登录结果为31登录来源为1次数     21
# 180                    上上段交易内交易时间11-12点     21
# 181            本次登录设备登录结果为正数在20min内登录次数     21
# 182                  1h内登录结果为1登录来源为10次数     20
# 183                       30min内登录不同城市数     20
# 184            本次登录设备登录结果为负数在10min内登录次数     20
# 185                   10min内登录不同城市数结果为1     19
# 186           本次登录设备登录结果为负数在30_45d内登录次数     19
# 187                     1d内登录不同IP数结果为31     19
# 188                      2h内登录不同IP数结果为1     18
# 189                             本段交易为周四     18
# 190                         上上段交易内交易为周一     18
# 191                  本次登录设备15min内连接IP次数     16
# 192                      45min内登录结果为1次数     16
# 193                     10min内登录结果为正数次数     16
# 194                        本段交易时间21-23点     16
# 195                   30min内登录不同设备数结果为1     16
# 196                     1d内登录不同IP数结果为负数     16
# 197              上段交易登录设备登录结果为1在1h内登录次数     15
# 198                 上段交易登录设备在30min内登录次数     15
# 199            上段交易登录设备登录结果为1在3_7d内登录次数     14
# 200             本次登录设备2_7d内登录其他用户次数结果为1     14
# 201                      6h内登录不同城市数结果为1     14
# 202            本次登录设备登录结果为正数在30min内登录次数     14
# 203                  30min内登录不同设备数结果为负数     14
# 204              本次登录设备登录结果为1在3_7d内登录次数     14
# 205                        本段交易时间18-20点     14
# 206                      6h内登录不同IP数结果为1     14
# 207                    上上段交易内交易时间18-20点     14
# 208                     6h内登录不同城市数结果为31     13
# 209                          2h内登录不同设备数     13
# 210           上段交易登录设备登录结果为1在7_14d内登录次数     13
# 211          上段交易登录设备登录结果为31在2h_1d内登录次数     13
# 212                  2h内登录结果为31登录来源为1次数     13
# 213            本次登录设备登录结果为负数在30min内登录次数     12
# 214             本次登录设备登录结果为31在1_3d内登录次数     12
# 215                       30min内登录不同IP数     12
# 216                     上段交易内交易时间18-20点     12
# 217                    上上段交易内交易时间13-17点     12
# 218                          本段交易是否为节假日     12
# 219                   30min内登录不同IP数结果为1     12
# 220                             本段交易为周二     12
# 221                     10min内登录结果为31次数     11
# 222                   本次登录设备5min内连接IP次数     11
# 223                     2h内登录不同设备数结果为正数     11
# 224                  2h内登录结果为1登录来源为10次数     11
# 225                         本段交易时间4-10点     11
# 226          本次登录设备45_60d内登录其他用户次数结果为正数     10
# 227                          上段交易内交易为周六     10
# 228               本次登录设备登录结果为正数在1h内登录次数     10
# 229                   本次登录IP在1_2h内被登录次数     10
# 230                  本次登录设备60min内连接IP次数     10
# 231                   本次登录设备在30min内登录次数     10
# 232                         上上段交易内交易为周二     10
# 233                  上上段登录设备5min内连接IP次数      9
# 234           上段交易登录设备登录结果为1在2h_1d内登录次数      9
# 235                   10min内登录不同设备数结果为1      9
# 236              上段交易1h内登录结果为1登录来源为10次数      9
# 237               本次登录设备登录结果为31在1h内登录次数      9
# 238            本次登录设备登录结果为正数在10min内登录次数      9
# 239           上段交易登录设备登录结果为1在20min内登录次数      8
# 240                     6h内登录不同设备数结果为负数      8
# 241            本次登录设备登录结果为31在20min内登录次数      8
# 242               20min内登录结果为31登录来源为2次数      8
# 243             上上段交易2h内登录结果为1登录来源为10次数      8
# 244               本次登录IP在30min_1h内被登录次数      7
# 245                   本次登录IP在3_7d内被登录次数      7
# 246              本次登录设备历史内登录其他用户次数结果为正数      7
# 247                  2h内登录结果为31登录来源为2次数      7
# 248               本次登录设备45_60d内登录其他用户次数      7
# 249          上段交易登录设备登录结果为31在30min内登录次数      7
# 250         上上段交易登录设备登录结果为31在10min内登录次数      7
# 251                 上上段交易登录设备在3_7d内登录次数      7
# 252                   30min内登录不同城市数结果为1      7
# 253          上段交易登录设备登录结果为负数在10min内登录次数      7
# 254          上段交易登录设备登录结果为31在20min内登录次数      6
# 255               20min内登录结果为1登录来源为10次数      6
# 256                  本次登录设备15min内连接城市次数      6
# 257                     1d内登录不同城市数结果为正数      6
# 258                    本次登录设备在3_7d内登录次数      6
# 259                    本次登录设备在1_2h内登录次数      6
# 260                    上上段交易内交易时间21-23点      6
# 261                上上段交易登录设备在30min内登录次数      6
# 262                上段交易登录设备15min内连接IP次数      5
# 263                  30min内登录不同设备数结果为31      5
# 264                  上段交易登录设备在1_2h内登录次数      5
# 265                      2h内登录不同城市数结果为1      5
# 266             本次登录设备登录结果为1在20min内登录次数      5
# 267           上段交易登录设备登录结果为1在30min内登录次数      5
# 268                  1h内登录结果为31登录来源为1次数      5
# 269                  本次登录设备30min内连接城市次数      5
# 270               上段交易1h内登录结果为1登录来源为1次数      5
# 271                    120min内登录结果为负数次数      5
# 272                     45min内登录结果为负数次数      4
# 273               上段交易2h内登录结果为1登录来源为2次数      4
# 274              上上段交易2h内登录结果为1登录来源为1次数      4
# 275                上上段交易登录设备在7_14d内登录次数      4
# 276            上段交易20min内登录结果为1登录来源为1次数      4
# 277            本次登录设备登录结果为负数在2h_1d内登录次数      4
# 278              上段交易2h内登录结果为31登录来源为1次数      4
# 279                 上段交易登录设备在10min内登录次数      4
# 280                         上上段交易内交易为周五      4
# 281                     6h内登录不同设备数结果为正数      4
# 282          上上段交易登录设备登录结果为负数在1_3d内登录次数      3
# 283                         上上段交易内交易为周六      3
# 284         上段交易登录设备登录结果为31在30_45d内登录次数      3
# 285             本次登录设备登录结果为31在1_2h内登录次数      3
# 286            本次登录设备登录结果为31在30min内登录次数      3
# 287                   本次登录设备5min内连接城市次数      3
# 288                     2h内登录不同城市数结果为31      3
# 289                     45min内登录结果为正数次数      3
# 290                     2h内登录不同城市数结果为正数      3
# 291            上段交易20min内登录结果为1登录来源为2次数      3
# 292               上段交易1h内登录结果为1登录来源为2次数      3
# 293                    120min内登录结果为正数次数      3
# 294                  10min内登录不同设备数结果为正数      3
# 295                  10min内登录不同设备数结果为负数      3
# 296            上段交易登录设备登录结果为1在1_2h内登录次数      2
# 297                      上上段交易内交易是否为节假日      2
# 298               本次登录设备1h内登录其他用户次数结果为1      2
# 299            本次登录设备20min内登录其他用户次数结果为1      2
# 300                     90min内登录结果为负数次数      2
# 301              上上段交易2h内登录结果为1登录来源为2次数      2
# 302              本次登录设备登录结果为1在1_2h内登录次数      2
# 303             本次登录设备2_6h内登录其他用户次数结果为1      2
# 304                   本次登录设备2h内登录其他用户次数      2
# 305                上上段交易登录设备在10min内登录次数      2
# 306                  30min内登录不同IP数结果为负数      2
# 307                     6h内登录不同IP数结果为负数      2
# 308                  30min内登录不同城市数结果为负数      2
# 309                         上上段交易内交易为周四      2
# 310                     20min内登录结果为正数次数      1
# 311                 上段交易登录设备5min内连接IP次数      1
# 312                  1h内登录结果为31登录来源为2次数      1
# 313                  30min内登录不同设备数结果为正数      1
# 314                     6h内登录不同IP数结果为正数      1
# 315              上段交易1h内登录结果为31登录来源为1次数      1
# 316                上段交易登录设备30min内连接城市次数      1
# 317              上上段交易1h内登录结果为1登录来源为1次数      1
# 318                     6h内登录不同城市数结果为负数      1
# 319           上上段交易登录设备登录结果为1在3_7d内登录次数      1
# 320          上上段交易登录设备登录结果为1在30min内登录次数      1
# 321  本次登录20min内登录存在登录结果为1后结果为其他的情况且设备不同      1
# 322                   上上段交易登录设备在1h内登录次数      1
# 323                 上上段交易登录设备在1_3d内登录次数      1
# 324                     2h内登录不同城市数结果为负数      1
# 325             上上段交易2h内登录结果为31登录来源为2次数      1
# 326              上上段交易1h内登录结果为1登录来源为2次数      1
# 327                     2h内登录不同设备数结果为负数      1
# 328           本次登录设备20min内登录其他用户次数结果为31      1
# 329          上上段交易登录设备登录结果为31在1_3d内登录次数      1
# 330           上段交易登录设备登录结果为31在1_2h内登录次数      1
# 331              上段交易2h内登录结果为31登录来源为2次数      1
# 332                 上上段登录设备15min内连接城市次数      1
# 333           上段交易登录设备登录结果为31在3_7d内登录次数      1
# 334          上段交易登录设备登录结果为31在7_14d内登录次数      1
# 335           上段交易20min内登录结果为1登录来源为10次数      1
# 336                上段交易登录设备30min内连接IP次数      1
# 337                  10min内登录不同设备数结果为31      1
# 338                  30min内登录不同IP数结果为31      1
# 339          本次登录设备30_45d内登录其他用户次数结果为31      1
# 340         上上段交易登录设备登录结果为31在20min内登录次数      1
# 341              本次登录设备1h内登录其他用户次数结果为31      1
# 342         上上段交易登录设备登录结果为31在30min内登录次数      1
# 343              本次登录设备2h内登录其他用户次数结果为31      1
# 344          上上段交易登录设备登录结果为1在20min内登录次数      0
# 345          上上段交易登录设备登录结果为1在10min内登录次数      0
# 346         上上段交易登录设备登录结果为正数在2h_1d内登录次数      0
# 347          上上段交易登录设备登录结果为正数在1_3d内登录次数      0
# 348            上上段交易登录设备登录结果为负数在1h内登录次数      0
# 349          上上段交易登录设备登录结果为正数在1_2h内登录次数      0
# 350         上上段交易登录设备登录结果为负数在30min内登录次数      0
# 351        上上段交易登录设备登录结果为负数在30_45d内登录次数      0
# 352            上上段交易登录设备登录结果为正数在1h内登录次数      0
# 353               上上段交易登录设备在14_30d内登录次数      0
# 354        上上段交易登录设备登录结果为负数在14_30d内登录次数      0
# 355         上上段交易登录设备登录结果为负数在7_14d内登录次数      0
# 356         上上段交易登录设备登录结果为负数在2h_1d内登录次数      0
# 357          上上段交易登录设备登录结果为负数在3_7d内登录次数      0
# 358          上上段交易登录设备登录结果为负数在1_2h内登录次数      0
# 359             上上段交易登录设备登录结果为1在1h内登录次数      0
# 360         上上段交易登录设备登录结果为31在2h_1d内登录次数      0
# 361         上上段交易登录设备登录结果为正数在30min内登录次数      0
# 362          上上段交易登录设备登录结果为31在1_2h内登录次数      0
# 363          上上段交易登录设备登录结果为31在3_7d内登录次数      0
# 364         上上段交易登录设备登录结果为31在7_14d内登录次数      0
# 365            上上段交易登录设备登录结果为31在1h内登录次数      0
# 366        上上段交易登录设备登录结果为31在14_30d内登录次数      0
# 367        上上段交易登录设备登录结果为31在30_45d内登录次数      0
# 368         上上段交易登录设备登录结果为负数在10min内登录次数      0
# 369           上上段交易登录设备登录结果为1在1_2h内登录次数      0
# 370         上上段交易登录设备登录结果为正数在20min内登录次数      0
# 371         上上段交易登录设备登录结果为负数在20min内登录次数      0
# 372          上上段交易登录设备登录结果为1在7_14d内登录次数      0
# 373         上上段交易登录设备登录结果为1在14_30d内登录次数      0
# 374           上上段交易登录设备登录结果为1在1_3d内登录次数      0
# 375          上上段交易登录设备登录结果为1在2h_1d内登录次数      0
# 376         上上段交易登录设备登录结果为正数在10min内登录次数      0
# 377                  10min内登录不同城市数结果为正数      0
# 378                上上段交易登录设备在2h_1d内登录次数      0
# 379          上段交易登录设备登录结果为负数在20min内登录次数      0
# 380                 历史登录设备5min内连接IP平均次数      0
# 381                历史登录设备15min内连接IP平均次数      0
# 382         上段交易登录设备登录结果为31在14_30d内登录次数      0
# 383                历史登录设备30min内连接IP平均次数      0
# 384                历史登录设备60min内连接IP平均次数      0
# 385           上段交易登录设备登录结果为31在1_3d内登录次数      0
# 386                  本次登录设备60min内连接城市次数      0
# 387                 上段交易登录设备5min内连接城市次数      0
# 388                上段交易登录设备15min内连接城市次数      0
# 389                上段交易登录设备60min内连接城市次数      0
# 390                  上上段登录设备5min内连接城市次数      0
# 391          上段交易登录设备登录结果为1在14_30d内登录次数      0
# 392                 上上段登录设备30min内连接城市次数      0
# 393                 上上段登录设备60min内连接城市次数      0
# 394                 历史登录设备5min内连接城市平均次数      0
# 395                历史登录设备15min内连接城市平均次数      0
# 396                历史登录设备30min内连接城市平均次数      0
# 397                历史登录设备60min内连接城市平均次数      0
# 398       本次登录10min内登录存在登录结果为1后结果为其他的情况      0
# 399       本次登录20min内登录存在登录结果为1后结果为其他的情况      0
# 400  本次登录10min内登录存在登录结果为1后结果为其他的情况且设备不同      0
# 401                 上上段登录设备60min内连接IP次数      0
# 402          上段交易登录设备登录结果为负数在30min内登录次数      0
# 403                 上上段交易登录设备在1_2h内登录次数      0
# 404                 上上段登录设备30min内连接IP次数      0
# 405         上段交易登录设备登录结果为正数在14_30d内登录次数      0
# 406          上段交易登录设备登录结果为正数在7_14d内登录次数      0
# 407           上段交易登录设备登录结果为正数在3_7d内登录次数      0
# 408           上段交易登录设备登录结果为正数在1_3d内登录次数      0
# 409          上段交易登录设备登录结果为正数在2h_1d内登录次数      0
# 410           上段交易登录设备登录结果为正数在1_2h内登录次数      0
# 411             上段交易登录设备登录结果为正数在1h内登录次数      0
# 412          上段交易登录设备登录结果为正数在30min内登录次数      0
# 413          上段交易登录设备登录结果为正数在20min内登录次数      0
# 414          上段交易登录设备登录结果为正数在10min内登录次数      0
# 415         上段交易登录设备登录结果为负数在30_45d内登录次数      0
# 416         上段交易登录设备登录结果为负数在14_30d内登录次数      0
# 417          上段交易登录设备登录结果为负数在7_14d内登录次数      0
# 418           上段交易登录设备登录结果为负数在3_7d内登录次数      0
# 419           上段交易登录设备登录结果为负数在1_3d内登录次数      0
# 420          上段交易登录设备登录结果为负数在2h_1d内登录次数      0
# 421           上段交易登录设备登录结果为负数在1_2h内登录次数      0
# 422                上段交易登录设备60min内连接IP次数      0
# 423                 上上段登录设备15min内连接IP次数      0
# 424         上上段交易登录设备登录结果为正数在7_14d内登录次数      0
# 425             上段交易登录设备登录结果为负数在1h内登录次数      0
# 426          上上段交易登录设备登录结果为正数在3_7d内登录次数      0
# 427           历史交易登录设备登录结果为负数在1h内平均登录次数      0
# 428        上上段交易登录设备登录结果为正数在14_30d内登录次数      0
# 429            本次登录设备6_12h内登录其他用户次数结果为1      0
# 430           本次登录设备20min内登录其他用户次数结果为负数      0
# 431           本次登录设备30min内登录其他用户次数结果为负数      0
# 432              本次登录设备1h内登录其他用户次数结果为负数      0
# 433              本次登录设备2h内登录其他用户次数结果为负数      0
# 434            本次登录设备2_6h内登录其他用户次数结果为负数      0
# 435           本次登录设备6_12h内登录其他用户次数结果为负数      0
# 436          本次登录设备12h_1d内登录其他用户次数结果为负数      0
# 437            本次登录设备1_2d内登录其他用户次数结果为负数      0
# 438            本次登录设备2_7d内登录其他用户次数结果为负数      0
# 439           本次登录设备7_14d内登录其他用户次数结果为负数      0
# 440          本次登录设备14_30d内登录其他用户次数结果为负数      0
# 441          本次登录设备30_45d内登录其他用户次数结果为负数      0
# 442          本次登录设备45_60d内登录其他用户次数结果为负数      0
# 443              本次登录设备历史内登录其他用户次数结果为负数      0
# 444            本次登录设备3min内登录其他用户次数结果为正数      0
# 445           本次登录设备10min内登录其他用户次数结果为负数      0
# 446            本次登录设备3min内登录其他用户次数结果为负数      0
# 447              本次登录设备历史内登录其他用户次数结果为31      0
# 448           本次登录设备10min内登录其他用户次数结果为31      0
# 449             本次登录设备1_2d内登录其他用户次数结果为1      0
# 450            本次登录设备7_14d内登录其他用户次数结果为1      0
# 451           本次登录设备14_30d内登录其他用户次数结果为1      0
# 452                     10min内登录结果为负数次数      0
# 453                     3天内交易时间11-12点次数      0
# 454            本次登录设备3min内登录其他用户次数结果为31      0
# 455           本次登录设备30min内登录其他用户次数结果为31      0
# 456                     1d内登录不同IP数结果为正数      0
# 457            本次登录设备2_6h内登录其他用户次数结果为31      0
# 458           本次登录设备6_12h内登录其他用户次数结果为31      0
# 459          本次登录设备12h_1d内登录其他用户次数结果为31      0
# 460            本次登录设备2_7d内登录其他用户次数结果为31      0
# 461           本次登录设备7_14d内登录其他用户次数结果为31      0
# 462          本次登录设备14_30d内登录其他用户次数结果为31      0
# 463           本次登录设备10min内登录其他用户次数结果为正数      0
# 464           本次登录设备20min内登录其他用户次数结果为正数      0
# 465           本次登录设备30min内登录其他用户次数结果为正数      0
# 466                             3天内交易段数      0
# 467                     2h内登录不同IP数结果为31      0
# 468                         3天内交易最大间隔天数      0
# 469                      3天登录与交易的最大时间间隔      0
# 470                  10min内登录不同IP数结果为31      0
# 471                         3天内交易平均间隔天数      0
# 472                      3天登录与交易的平均时间间隔      0
# 473                 本次登录城市在14_30d内被登录次数      0
# 474                      3天登录与交易的最小时间间隔      0
# 475                 本次登录IP在14_30d内被登录次数      0
# 476                     6h内登录不同城市数结果为正数      0
# 477                  10min内登录不同城市数结果为31      0
# 478                  30min内登录不同城市数结果为31      0
# 479                  30min内登录不同城市数结果为正数      0
# 480                  10min内登录不同城市数结果为负数      0
# 481                  10min内登录不同IP数结果为负数      0
# 482                     2h内登录不同IP数结果为负数      0
# 483              本次登录设备1h内登录其他用户次数结果为正数      0
# 484           本次登录设备7_14d内登录其他用户次数结果为正数      0
# 485              本次登录设备2h内登录其他用户次数结果为正数      0
# 486            本次登录设备2_6h内登录其他用户次数结果为正数      0
# 487           本次登录设备6_12h内登录其他用户次数结果为正数      0
# 488          本次登录设备12h_1d内登录其他用户次数结果为正数      0
# 489            本次登录设备1_2d内登录其他用户次数结果为正数      0
# 490            本次登录设备2_7d内登录其他用户次数结果为正数      0
# 491          本次登录设备14_30d内登录其他用户次数结果为正数      0
# 492                         3天内交易最小间隔天数      0
# 493          本次登录设备30_45d内登录其他用户次数结果为正数      0
# 494                     2h内登录不同IP数结果为正数      0
# 495                      3天内交易时间4-10点次数      0
# 496                       3天内交易时间0-3点次数      0
# 497                  30min内登录不同IP数结果为正数      0
# 498                  10min内登录不同IP数结果为正数      0
# 499           本次登录设备12h_1d内登录其他用户次数结果为1      0
# 500            本次登录设备30min内登录其他用户次数结果为1      0
# 501        上上段交易登录设备登录结果为正数在30_45d内登录次数      0
# 502            本次登录设备10min内登录其他用户次数结果为1      0
# 503         历史交易登录设备登录结果为1在7_14d内平均登录次数      0
# 504        历史交易登录设备登录结果为1在14_30d内平均登录次数      0
# 505        历史交易登录设备登录结果为1在30_45d内平均登录次数      0
# 506        历史交易登录设备登录结果为31在10min内平均登录次数      0
# 507        历史交易登录设备登录结果为31在20min内平均登录次数      0
# 508        历史交易登录设备登录结果为31在30min内平均登录次数      0
# 509           历史交易登录设备登录结果为31在1h内平均登录次数      0
# 510         历史交易登录设备登录结果为31在1_2h内平均登录次数      0
# 511        历史交易登录设备登录结果为31在2h_1d内平均登录次数      0
# 512         历史交易登录设备登录结果为31在1_3d内平均登录次数      0
# 513         历史交易登录设备登录结果为31在3_7d内平均登录次数      0
# 514        历史交易登录设备登录结果为31在7_14d内平均登录次数      0
# 515       历史交易登录设备登录结果为31在14_30d内平均登录次数      0
# 516       历史交易登录设备登录结果为31在30_45d内平均登录次数      0
# 517        历史交易登录设备登录结果为负数在10min内平均登录次数      0
# 518          历史交易登录设备登录结果为1在3_7d内平均登录次数      0
# 519          历史交易登录设备登录结果为1在1_3d内平均登录次数      0
# 520         历史交易登录设备登录结果为1在2h_1d内平均登录次数      0
# 521                历史交易登录设备在3_7d内平均登录次数      0
# 522               历史交易登录设备在10min内平均登录次数      0
# 523               历史交易登录设备在30min内平均登录次数      0
# 524                  历史交易登录设备在1h内平均登录次数      0
# 525                历史交易登录设备在1_2h内平均登录次数      0
# 526               历史交易登录设备在2h_1d内平均登录次数      0
# 527                历史交易登录设备在1_3d内平均登录次数      0
# 528               历史交易登录设备在7_14d内平均登录次数      0
# 529          历史交易登录设备登录结果为1在1_2h内平均登录次数      0
# 530              历史交易登录设备在14_30d内平均登录次数      0
# 531              历史交易登录设备在30_45d内平均登录次数      0
# 532         历史交易登录设备登录结果为1在10min内平均登录次数      0
# 533         历史交易登录设备登录结果为1在20min内平均登录次数      0
# 534         历史交易登录设备登录结果为1在30min内平均登录次数      0
# 535            历史交易登录设备登录结果为1在1h内平均登录次数      0
# 536        历史交易登录设备登录结果为负数在20min内平均登录次数      0
# 537        历史交易登录设备登录结果为负数在30min内平均登录次数      0
# 538         历史交易登录设备登录结果为负数在1_2h内平均登录次数      0
# 539               本次登录设备12h_1d内登录其他用户次数      0
# 540                     90min内登录结果为正数次数      0
# 541                本次登录设备20min内登录其他用户次数      0
# 542                本次登录设备30min内登录其他用户次数      0
# 543                   本次登录设备1h内登录其他用户次数      0
# 544                 本次登录设备2_6h内登录其他用户次数      0
# 545                本次登录设备6_12h内登录其他用户次数      0
# 546                 本次登录设备1_2d内登录其他用户次数      0
# 547                 本次登录设备3min内登录其他用户次数      0
# 548                 本次登录设备2_7d内登录其他用户次数      0
# 549                本次登录设备7_14d内登录其他用户次数      0
# 550               本次登录设备14_30d内登录其他用户次数      0
# 551               本次登录设备30_45d内登录其他用户次数      0
# 552                   本次登录设备历史内登录其他用户次数      0
# 553             本次登录设备3min内登录其他用户次数结果为1      0
# 554                本次登录设备10min内登录其他用户次数      0
# 555       历史交易登录设备登录结果为正数在30_45d内平均登录次数      0
# 556        历史交易登录设备登录结果为负数在2h_1d内平均登录次数      0
# 557        历史交易登录设备登录结果为正数在20min内平均登录次数      0
# 558         历史交易登录设备登录结果为负数在1_3d内平均登录次数      0
# 559         历史交易登录设备登录结果为负数在3_7d内平均登录次数      0
# 560        历史交易登录设备登录结果为负数在7_14d内平均登录次数      0
# 561       历史交易登录设备登录结果为负数在14_30d内平均登录次数      0
# 562       历史交易登录设备登录结果为负数在30_45d内平均登录次数      0
# 563        历史交易登录设备登录结果为正数在10min内平均登录次数      0
# 564        历史交易登录设备登录结果为正数在30min内平均登录次数      0
# 565       历史交易登录设备登录结果为正数在14_30d内平均登录次数      0
# 566           历史交易登录设备登录结果为正数在1h内平均登录次数      0
# 567         历史交易登录设备登录结果为正数在1_2h内平均登录次数      0
# 568        历史交易登录设备登录结果为正数在2h_1d内平均登录次数      0
# 569         历史交易登录设备登录结果为正数在1_3d内平均登录次数      0
# 570         历史交易登录设备登录结果为正数在3_7d内平均登录次数      0
# 571        历史交易登录设备登录结果为正数在7_14d内平均登录次数      0
# 572            本次登录设备1_2d内登录其他用户次数结果为31      0
# 573                         3_14天内交易为周日      0
# 574                上段交易登录设备在14_30d内登录次数      0
# 575              20min内登录结果为其他登录来源为16次数      0
# 576               20min内登录结果为其他登录来源为3次数      0
# 577              20min内登录结果为其他登录来源为12次数      0
# 578                  1h内登录结果为1登录来源为11次数      0
# 579                  1h内登录结果为1登录来源为21次数      0
# 580                   1h内登录结果为1登录来源为5次数      0
# 581                   1h内登录结果为1登录来源为8次数      0
# 582                  1h内登录结果为1登录来源为16次数      0
# 583                  1h内登录结果为1登录来源为18次数      0
# 584                   1h内登录结果为1登录来源为3次数      0
# 585                  1h内登录结果为1登录来源为12次数      0
# 586                 1h内登录结果为31登录来源为10次数      0
# 587                 1h内登录结果为31登录来源为11次数      0
# 588                 1h内登录结果为31登录来源为21次数      0
# 589                  1h内登录结果为31登录来源为5次数      0
# 590                  1h内登录结果为31登录来源为8次数      0
# 591                 1h内登录结果为31登录来源为16次数      0
# 592                 1h内登录结果为31登录来源为18次数      0
# 593                  1h内登录结果为31登录来源为3次数      0
# 594                 1h内登录结果为31登录来源为12次数      0
# 595                 1h内登录结果为其他登录来源为10次数      0
# 596                  1h内登录结果为其他登录来源为1次数      0
# 597              20min内登录结果为其他登录来源为18次数      0
# 598               20min内登录结果为其他登录来源为8次数      0
# 599           上段交易20min内登录结果为31登录来源为5次数      0
# 600               20min内登录结果为其他登录来源为5次数      0
# 601               20min内登录结果为1登录来源为21次数      0
# 602                20min内登录结果为1登录来源为5次数      0
# 603                20min内登录结果为1登录来源为8次数      0
# 604               20min内登录结果为1登录来源为16次数      0
# 605               20min内登录结果为1登录来源为18次数      0
# 606                20min内登录结果为1登录来源为3次数      0
# 607               20min内登录结果为1登录来源为12次数      0
# 608              20min内登录结果为31登录来源为10次数      0
# 609              20min内登录结果为31登录来源为11次数      0
# 610              20min内登录结果为31登录来源为21次数      0
# 611               20min内登录结果为31登录来源为5次数      0
# 612               20min内登录结果为31登录来源为8次数      0
# 613              20min内登录结果为31登录来源为16次数      0
# 614              20min内登录结果为31登录来源为18次数      0
# 615               20min内登录结果为31登录来源为3次数      0
# 616              20min内登录结果为31登录来源为12次数      0
# 617              20min内登录结果为其他登录来源为10次数      0
# 618               20min内登录结果为其他登录来源为1次数      0
# 619               20min内登录结果为其他登录来源为2次数      0
# 620              20min内登录结果为其他登录来源为11次数      0
# 621              20min内登录结果为其他登录来源为21次数      0
# 622                  1h内登录结果为其他登录来源为2次数      0
# 623                 1h内登录结果为其他登录来源为11次数      0
# 624                 1h内登录结果为其他登录来源为21次数      0
# 625                  1h内登录结果为其他登录来源为5次数      0
# 626                  2h内登录结果为其他登录来源为2次数      0
# 627                 2h内登录结果为其他登录来源为11次数      0
# 628                 2h内登录结果为其他登录来源为21次数      0
# 629                  2h内登录结果为其他登录来源为5次数      0
# 630                  2h内登录结果为其他登录来源为8次数      0
# 631                 2h内登录结果为其他登录来源为16次数      0
# 632                 2h内登录结果为其他登录来源为18次数      0
# 633                  2h内登录结果为其他登录来源为3次数      0
# 634                 2h内登录结果为其他登录来源为12次数      0
# 635           上段交易20min内登录结果为1登录来源为11次数      0
# 636           上段交易20min内登录结果为1登录来源为21次数      0
# 637            上段交易20min内登录结果为1登录来源为5次数      0
# 638            上段交易20min内登录结果为1登录来源为8次数      0
# 639           上段交易20min内登录结果为1登录来源为16次数      0
# 640           上段交易20min内登录结果为1登录来源为18次数      0
# 641            上段交易20min内登录结果为1登录来源为3次数      0
# 642           上段交易20min内登录结果为1登录来源为12次数      0
# 643          上段交易20min内登录结果为31登录来源为10次数      0
# 644           上段交易20min内登录结果为31登录来源为1次数      0
# 645           上段交易20min内登录结果为31登录来源为2次数      0
# 646          上段交易20min内登录结果为31登录来源为11次数      0
# 647                  2h内登录结果为其他登录来源为1次数      0
# 648                 2h内登录结果为其他登录来源为10次数      0
# 649                 2h内登录结果为31登录来源为12次数      0
# 650                  2h内登录结果为1登录来源为16次数      0
# 651                  1h内登录结果为其他登录来源为8次数      0
# 652                 1h内登录结果为其他登录来源为16次数      0
# 653                 1h内登录结果为其他登录来源为18次数      0
# 654                  1h内登录结果为其他登录来源为3次数      0
# 655                 1h内登录结果为其他登录来源为12次数      0
# 656                  2h内登录结果为1登录来源为11次数      0
# 657                  2h内登录结果为1登录来源为21次数      0
# 658                   2h内登录结果为1登录来源为5次数      0
# 659                   2h内登录结果为1登录来源为8次数      0
# 660                  2h内登录结果为1登录来源为18次数      0
# 661                  2h内登录结果为31登录来源为3次数      0
# 662                   2h内登录结果为1登录来源为3次数      0
# 663                  2h内登录结果为1登录来源为12次数      0
# 664                 2h内登录结果为31登录来源为10次数      0
# 665                 2h内登录结果为31登录来源为11次数      0
# 666                 2h内登录结果为31登录来源为21次数      0
# 667                  2h内登录结果为31登录来源为5次数      0
# 668                  2h内登录结果为31登录来源为8次数      0
# 669                 2h内登录结果为31登录来源为16次数      0
# 670                 2h内登录结果为31登录来源为18次数      0
# 671               20min内登录结果为1登录来源为11次数      0
# 672                            3天内交易为周二      0
# 673                           本次登录来源为12      0
# 674                        30_60天内交易为周四      0
# 675                         30_60天内交易段数      0
# 676                  30_60天登录与交易的平均时间间隔      0
# 677                     30_60天内交易平均间隔天数      0
# 678                  30_60天登录与交易的最大时间间隔      0
# 679                     30_60天内交易最大间隔天数      0
# 680                  30_60天登录与交易的最小时间间隔      0
# 681                     30_60天内交易最小间隔天数      0
# 682                   30_60天内交易时间0-3点次数      0
# 683                  30_60天内交易时间4-10点次数      0
# 684                 30_60天内交易时间11-12点次数      0
# 685                 30_60天内交易时间13-17点次数      0
# 686                 30_60天内交易时间18-20点次数      0
# 687                 30_60天内交易时间21-23点次数      0
# 688                   30_60天内交易时间0-3点占比      0
# 689                  30_60天内交易时间4-10点占比      0
# 690                 30_60天内交易时间11-12点占比      0
# 691                 30_60天内交易时间13-17点占比      0
# 692                 30_60天内交易时间18-20点占比      0
# 693                 30_60天内交易时间21-23点占比      0
# 694                        30_60天内交易为周一      0
# 695                        30_60天内交易为周二      0
# 696                      3_14天内交易平均间隔天数      0
# 697                   3_14天登录与交易的最大时间间隔      0
# 698                      3_14天内交易最大间隔天数      0
# 699                  3_14天内交易时间13-17点占比      0
# 700                   3_14天内交易是否为节假日前一天      0
# 701                         3_14天内交易为周六      0
# 702                         3_14天内交易为周五      0
# 703                         3_14天内交易为周四      0
# 704                         3_14天内交易为周三      0
# 705                         3_14天内交易为周二      0
# 706                         3_14天内交易为周一      0
# 707                  3_14天内交易时间21-23点占比      0
# 708                  3_14天内交易时间18-20点占比      0
# 709                  3_14天内交易时间11-12点占比      0
# 710                   3_14天登录与交易的最小时间间隔      0
# 711                   3_14天内交易时间4-10点占比      0
# 712                    3_14天内交易时间0-3点占比      0
# 713                  3_14天内交易时间21-23点次数      0
# 714                  3_14天内交易时间18-20点次数      0
# 715                  3_14天内交易时间13-17点次数      0
# 716                  3_14天内交易时间11-12点次数      0
# 717                   3_14天内交易时间4-10点次数      0
# 718                    3_14天内交易时间0-3点次数      0
# 719                      3_14天内交易最小间隔天数      0
# 720                        30_60天内交易为周三      0
# 721                        30_60天内交易为周五      0
# 722                            本次登录来源为3      0
# 723                        30_60天内交易为周六      0
# 724                            历史内交易为周三      0
# 725                            历史内交易为周四      0
# 726                            历史内交易为周五      0
# 727                            历史内交易为周六      0
# 728                            历史内交易为周日      0
# 729                         历史内交易是否为节假日      0
# 730                      历史内交易是否为节假日前一天      0
# 731                   3_14天登录与交易的平均时间间隔      0
# 732                          3_14天内交易段数      0
# 733                      3天内交易是否为节假日前一天      0
# 734                         3天内交易是否为节假日      0
# 735                            3天内交易为周日      0
# 736                            3天内交易为周六      0
# 737                            3天内交易为周五      0
# 738                            3天内交易为周四      0
# 739                            3天内交易为周三      0
# 740                           本次登录来源为11      0
# 741                           本次登录来源为21      0
# 742                            本次登录来源为5      0
# 743                            本次登录来源为8      0
# 744                           本次登录来源为18      0
# 745                            历史内交易为周二      0
# 746                            历史内交易为周一      0
# 747                     历史内交易时间21-23点占比      0
# 748                         历史内交易最小间隔天数      0
# 749                        30_60天内交易为周日      0
# 750                     30_60天内交易是否为节假日      0
# 751                  30_60天内交易是否为节假日前一天      0
# 752                             历史内交易段数      0
# 753                      历史登录与交易的平均时间间隔      0
# 754                         历史内交易平均间隔天数      0
# 755                      历史登录与交易的最大时间间隔      0
# 756                         历史内交易最大间隔天数      0
# 757                      历史登录与交易的最小时间间隔      0
# 758                       历史内交易时间0-3点次数      0
# 759                     历史内交易时间18-20点占比      0
# 760                      历史内交易时间4-10点次数      0
# 761                     历史内交易时间11-12点次数      0
# 762                     历史内交易时间13-17点次数      0
# 763                     历史内交易时间18-20点次数      0
# 764                     历史内交易时间21-23点次数      0
# 765                       历史内交易时间0-3点占比      0
# 766                      历史内交易时间4-10点占比      0
# 767                     历史内交易时间11-12点占比      0
# 768                     历史内交易时间13-17点占比      0
# 769          上段交易20min内登录结果为31登录来源为21次数      0
# 770           上段交易20min内登录结果为31登录来源为8次数      0
# 771               本次登录设备登录结果为正数在历史内登录次数      0
# 772            上上段交易1h内登录结果为31登录来源为18次数      0
# 773            上上段交易1h内登录结果为31登录来源为12次数      0
# 774            上上段交易1h内登录结果为其他登录来源为10次数      0
# 775             上上段交易1h内登录结果为其他登录来源为1次数      0
# 776             上上段交易1h内登录结果为其他登录来源为2次数      0
# 777            上上段交易1h内登录结果为其他登录来源为11次数      0
# 778            上上段交易1h内登录结果为其他登录来源为21次数      0
# 779             上上段交易1h内登录结果为其他登录来源为5次数      0
# 780             上上段交易1h内登录结果为其他登录来源为8次数      0
# 781            上上段交易1h内登录结果为其他登录来源为16次数      0
# 782            上上段交易1h内登录结果为其他登录来源为18次数      0
# 783             上上段交易1h内登录结果为其他登录来源为3次数      0
# 784            上上段交易1h内登录结果为其他登录来源为12次数      0
# 785             上上段交易2h内登录结果为1登录来源为11次数      0
# 786             上上段交易2h内登录结果为1登录来源为21次数      0
# 787              上上段交易2h内登录结果为1登录来源为5次数      0
# 788              上上段交易2h内登录结果为1登录来源为8次数      0
# 789             上上段交易2h内登录结果为1登录来源为16次数      0
# 790             上上段交易2h内登录结果为1登录来源为18次数      0
# 791              上上段交易2h内登录结果为1登录来源为3次数      0
# 792             上上段交易2h内登录结果为1登录来源为12次数      0
# 793            上上段交易2h内登录结果为31登录来源为10次数      0
# 794             上上段交易1h内登录结果为31登录来源为3次数      0
# 795            上上段交易1h内登录结果为31登录来源为16次数      0
# 796          上段交易20min内登录结果为31登录来源为16次数      0
# 797             上上段交易1h内登录结果为31登录来源为8次数      0
# 798          上上段交易20min内登录结果为其他登录来源为5次数      0
# 799          上上段交易20min内登录结果为其他登录来源为8次数      0
# 800         上上段交易20min内登录结果为其他登录来源为16次数      0
# 801         上上段交易20min内登录结果为其他登录来源为18次数      0
# 802          上上段交易20min内登录结果为其他登录来源为3次数      0
# 803         上上段交易20min内登录结果为其他登录来源为12次数      0
# 804             上上段交易1h内登录结果为1登录来源为10次数      0
# 805             上上段交易1h内登录结果为1登录来源为11次数      0
# 806             上上段交易1h内登录结果为1登录来源为21次数      0
# 807              上上段交易1h内登录结果为1登录来源为5次数      0
# 808              上上段交易1h内登录结果为1登录来源为8次数      0
# 809             上上段交易1h内登录结果为1登录来源为16次数      0
# 810             上上段交易1h内登录结果为1登录来源为18次数      0
# 811              上上段交易1h内登录结果为1登录来源为3次数      0
# 812             上上段交易1h内登录结果为1登录来源为12次数      0
# 813            上上段交易1h内登录结果为31登录来源为10次数      0
# 814             上上段交易1h内登录结果为31登录来源为1次数      0
# 815             上上段交易1h内登录结果为31登录来源为2次数      0
# 816            上上段交易1h内登录结果为31登录来源为11次数      0
# 817            上上段交易1h内登录结果为31登录来源为21次数      0
# 818             上上段交易1h内登录结果为31登录来源为5次数      0
# 819             上上段交易2h内登录结果为31登录来源为1次数      0
# 820            上上段交易2h内登录结果为31登录来源为11次数      0
# 821            上上段交易2h内登录结果为31登录来源为21次数      0
# 822             上上段交易2h内登录结果为31登录来源为5次数      0
# 823            本次登录设备登录结果为1在14_30d内登录次数      0
# 824                       3天内交易时间0-3点占比      0
# 825                     3天内交易时间21-23点次数      0
# 826             本次登录设备登录结果为31在3_7d内登录次数      0
# 827            本次登录设备登录结果为31在7_14d内登录次数      0
# 828           本次登录设备登录结果为31在14_30d内登录次数      0
# 829                     3天内交易时间18-20点次数      0
# 830               本次登录设备登录结果为负数在1h内登录次数      0
# 831             本次登录设备登录结果为负数在1_2h内登录次数      0
# 832             本次登录设备登录结果为负数在1_3d内登录次数      0
# 833             本次登录设备登录结果为负数在3_7d内登录次数      0
# 834            本次登录设备登录结果为负数在7_14d内登录次数      0
# 835           本次登录设备登录结果为负数在14_30d内登录次数      0
# 836               本次登录设备登录结果为负数在历史内登录次数      0
# 837             本次登录设备登录结果为正数在1_2h内登录次数      0
# 838            本次登录设备登录结果为正数在2h_1d内登录次数      0
# 839             本次登录设备登录结果为正数在1_3d内登录次数      0
# 840             本次登录设备登录结果为正数在3_7d内登录次数      0
# 841            本次登录设备登录结果为正数在7_14d内登录次数      0
# 842           本次登录设备登录结果为正数在14_30d内登录次数      0
# 843                     3天内交易时间13-17点次数      0
# 844                      3_14天内交易是否为节假日      0
# 845             本次登录设备登录结果为1在30min内登录次数      0
# 846                      3天内交易时间4-10点占比      0
# 847             上上段交易2h内登录结果为其他登录来源为5次数      0
# 848             上上段交易2h内登录结果为31登录来源为8次数      0
# 849            上上段交易2h内登录结果为31登录来源为16次数      0
# 850            上上段交易2h内登录结果为31登录来源为18次数      0
# 851            上上段交易2h内登录结果为31登录来源为12次数      0
# 852            上上段交易2h内登录结果为其他登录来源为10次数      0
# 853             上上段交易2h内登录结果为其他登录来源为1次数      0
# 854             上上段交易2h内登录结果为其他登录来源为2次数      0
# 855            上上段交易2h内登录结果为其他登录来源为11次数      0
# 856            上上段交易2h内登录结果为其他登录来源为21次数      0
# 857             上上段交易2h内登录结果为其他登录来源为8次数      0
# 858                     3天内交易时间11-12点占比      0
# 859            上上段交易2h内登录结果为其他登录来源为16次数      0
# 860            上上段交易2h内登录结果为其他登录来源为18次数      0
# 861             上上段交易2h内登录结果为其他登录来源为3次数      0
# 862            上上段交易2h内登录结果为其他登录来源为12次数      0
# 863                            3天内交易为周一      0
# 864                     3天内交易时间21-23点占比      0
# 865                     3天内交易时间18-20点占比      0
# 866                  本次登录设备在14_30d内登录次数      0
# 867                     3天内交易时间13-17点占比      0
# 868         上上段交易20min内登录结果为其他登录来源为21次数      0
# 869         上上段交易20min内登录结果为其他登录来源为11次数      0
# 870          上上段交易20min内登录结果为其他登录来源为2次数      0
# 871               上段交易2h内登录结果为1登录来源为8次数      0
# 872             上段交易1h内登录结果为31登录来源为11次数      0
# 873             上段交易1h内登录结果为31登录来源为21次数      0
# 874              上段交易1h内登录结果为31登录来源为5次数      0
# 875              上段交易1h内登录结果为31登录来源为8次数      0
# 876             上段交易1h内登录结果为31登录来源为16次数      0
# 877             上段交易1h内登录结果为31登录来源为18次数      0
# 878              上段交易1h内登录结果为31登录来源为3次数      0
# 879             上段交易1h内登录结果为31登录来源为12次数      0
# 880             上段交易1h内登录结果为其他登录来源为10次数      0
# 881              上段交易1h内登录结果为其他登录来源为1次数      0
# 882              上段交易1h内登录结果为其他登录来源为2次数      0
# 883             上段交易1h内登录结果为其他登录来源为11次数      0
# 884             上段交易1h内登录结果为其他登录来源为21次数      0
# 885              上段交易1h内登录结果为其他登录来源为5次数      0
# 886              上段交易1h内登录结果为其他登录来源为8次数      0
# 887             上段交易1h内登录结果为其他登录来源为16次数      0
# 888             上段交易1h内登录结果为其他登录来源为18次数      0
# 889              上段交易1h内登录结果为其他登录来源为3次数      0
# 890             上段交易1h内登录结果为其他登录来源为12次数      0
# 891              上段交易2h内登录结果为1登录来源为11次数      0
# 892              上段交易2h内登录结果为1登录来源为21次数      0
# 893              上段交易1h内登录结果为31登录来源为2次数      0
# 894             上段交易1h内登录结果为31登录来源为10次数      0
# 895              上段交易1h内登录结果为1登录来源为12次数      0
# 896           上段交易20min内登录结果为其他登录来源为8次数      0
# 897          上段交易20min内登录结果为31登录来源为18次数      0
# 898           上段交易20min内登录结果为31登录来源为3次数      0
# 899          上段交易20min内登录结果为31登录来源为12次数      0
# 900          上段交易20min内登录结果为其他登录来源为10次数      0
# 901           上段交易20min内登录结果为其他登录来源为1次数      0
# 902           上段交易20min内登录结果为其他登录来源为2次数      0
# 903          上段交易20min内登录结果为其他登录来源为11次数      0
# 904          上段交易20min内登录结果为其他登录来源为21次数      0
# 905           上段交易20min内登录结果为其他登录来源为5次数      0
# 906          上段交易20min内登录结果为其他登录来源为16次数      0
# 907               上段交易1h内登录结果为1登录来源为3次数      0
# 908          上段交易20min内登录结果为其他登录来源为18次数      0
# 909           上段交易20min内登录结果为其他登录来源为3次数      0
# 910          上段交易20min内登录结果为其他登录来源为12次数      0
# 911              上段交易1h内登录结果为1登录来源为11次数      0
# 912              上段交易1h内登录结果为1登录来源为21次数      0
# 913               上段交易1h内登录结果为1登录来源为5次数      0
# 914               上段交易1h内登录结果为1登录来源为8次数      0
# 915              上段交易1h内登录结果为1登录来源为16次数      0
# 916              上段交易1h内登录结果为1登录来源为18次数      0
# 917               上段交易2h内登录结果为1登录来源为5次数      0
# 918              上段交易2h内登录结果为1登录来源为16次数      0
# 919          上上段交易20min内登录结果为其他登录来源为1次数      0
# 920              上段交易2h内登录结果为1登录来源为18次数      0
# 921           上上段交易20min内登录结果为1登录来源为2次数      0
# 922          上上段交易20min内登录结果为1登录来源为11次数      0
# 923          上上段交易20min内登录结果为1登录来源为21次数      0
# 924           上上段交易20min内登录结果为1登录来源为5次数      0
# 925           上上段交易20min内登录结果为1登录来源为8次数      0
# 926          上上段交易20min内登录结果为1登录来源为16次数      0
# 927          上上段交易20min内登录结果为1登录来源为18次数      0
# 928           上上段交易20min内登录结果为1登录来源为3次数      0
# 929          上上段交易20min内登录结果为1登录来源为12次数      0
# 930         上上段交易20min内登录结果为31登录来源为10次数      0
# 931          上上段交易20min内登录结果为31登录来源为1次数      0
# 932          上上段交易20min内登录结果为31登录来源为2次数      0
# 933         上上段交易20min内登录结果为31登录来源为11次数      0
# 934         上上段交易20min内登录结果为31登录来源为21次数      0
# 935          上上段交易20min内登录结果为31登录来源为5次数      0
# 936          上上段交易20min内登录结果为31登录来源为8次数      0
# 937         上上段交易20min内登录结果为31登录来源为16次数      0
# 938         上上段交易20min内登录结果为31登录来源为18次数      0
# 939          上上段交易20min内登录结果为31登录来源为3次数      0
# 940         上上段交易20min内登录结果为31登录来源为12次数      0
# 941         上上段交易20min内登录结果为其他登录来源为10次数      0
# 942           上上段交易20min内登录结果为1登录来源为1次数      0
# 943          上上段交易20min内登录结果为1登录来源为10次数      0
# 944             上段交易2h内登录结果为其他登录来源为12次数      0
# 945              上段交易2h内登录结果为31登录来源为3次数      0
# 946               上段交易2h内登录结果为1登录来源为3次数      0
# 947              上段交易2h内登录结果为1登录来源为12次数      0
# 948             上段交易2h内登录结果为31登录来源为10次数      0
# 949             上段交易2h内登录结果为31登录来源为11次数      0
# 950             上段交易2h内登录结果为31登录来源为21次数      0
# 951              上段交易2h内登录结果为31登录来源为5次数      0
# 952              上段交易2h内登录结果为31登录来源为8次数      0
# 953             上段交易2h内登录结果为31登录来源为16次数      0
# 954             上段交易2h内登录结果为31登录来源为18次数      0
# 955             上段交易2h内登录结果为31登录来源为12次数      0
# 956              上段交易2h内登录结果为其他登录来源为3次数      0
# 957             上段交易2h内登录结果为其他登录来源为10次数      0
# 958              上段交易2h内登录结果为其他登录来源为1次数      0
# 959              上段交易2h内登录结果为其他登录来源为2次数      0
# 960             上段交易2h内登录结果为其他登录来源为11次数      0
# 961             上段交易2h内登录结果为其他登录来源为21次数      0
# 962              上段交易2h内登录结果为其他登录来源为5次数      0
# 963              上段交易2h内登录结果为其他登录来源为8次数      0
# 964             上段交易2h内登录结果为其他登录来源为16次数      0
# 965             上段交易2h内登录结果为其他登录来源为18次数      0
# 966             上上段交易2h内登录结果为31登录来源为3次数      0

# %%
test2 = test_df[['row_name']]

# %%
test2['clf4a_prob'] = clf4a.predict_proba(test_df[s_column_2])[:,1]
# Out:
# /Users/admin/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test2[test2.clf4a_prob >= 0.99].shape
# Out:
# (151, 2)

# %%
s1_1203 = pd.DataFrame(test2[test2.clf4a_prob >= 0.99]['row_name'])
s1_1203['label'] = 1
s1_1203 = pd.merge(trade_test, s1_1203, how='left', on='row_name')
s1_1203 = s1_1203.fillna(0)
s1_1203.label = s1_1203.label.astype(int)
s1_1203[['rowkey','label']].to_csv("c.csv",header=None,index=None)
